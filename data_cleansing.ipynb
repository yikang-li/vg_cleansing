# %% [markdown]
# # Visual Genome Dataset Cleansing
#
# Loading dataset
# -----------
#
# - To read data from the JSON file and remove the annotations with wrong spelling.

# %%
import numpy as np
import math
import sys

sys.path.append('./python_code')
import preprocessing_data as imported_data
# Out:
# Loading image data...
# image data length: 108077
# Loading Relationship data...
# relationship data length: 108077
# Loading caption dataset...
# caption dataset length: 108077
# Unspecified Error
# 3780
# 53
# (3780, 53): [chair]-[]-[outside]
#
# Error: [chair]-[]-[outside]
#
# 5000 images processed, 56608 relationships
# Unspecified Error
# 6768
# 22
# (6768, 22): [sky]-[]-[above]
#
# Error: [sky]-[]-[above]
#
# Unspecified Error
# 9782
# 4
# (9782, 4): [man]-[]-[sleeping]
#
# Error: [man]-[]-[sleeping]
#
# Unspecified Error
# 9834
# 27
# (9834, 27): [man]-[]-[bending over]
#
# Error: [man]-[]-[bending over]
#
# 10000 images processed, 86124 relationships
# Unspecified Error
# 14024
# 53
# (14024, 53): [ear]-[]-[side of head]
#
# Error: [ear]-[]-[side of head]
#
# Unspecified Error
# 14024
# 54
# (14024, 54): [ear]-[]-[side of head]
#
# Error: [ear]-[]-[side of head]
#
# 15000 images processed, 203671 relationships
# 20000 images processed, 309562 relationships
# 25000 images processed, 399991 relationships
# Unspecified Error
# 25565
# 36
# (25565, 36): [the]-[]-[sign]
#
# Error: [the]-[]-[sign]
#
# Unspecified Error
# 25597
# 24
# (25597, 24): [number]-[]-[sign]
#
# Error: [number]-[]-[sign]
#
# 30000 images processed, 480009 relationships
# Unspecified Error
# 30527
# 14
# (30527, 14): [leaves]-[]-[green]
#
# Error: [leaves]-[]-[green]
#
# Unspecified Error
# 30527
# 15
# (30527, 15): [leaves]-[]-[green]
#
# Error: [leaves]-[]-[green]
#
# Unspecified Error
# 30527
# 16
# (30527, 16): [leaves]-[]-[green]
#
# Error: [leaves]-[]-[green]
#
# Unspecified Error
# 30527
# 17
# (30527, 17): [leaves]-[]-[green]
#
# Error: [leaves]-[]-[green]
#
# Unspecified Error
# 30527
# 18
# (30527, 18): [leaves]-[]-[green]
#
# Error: [leaves]-[]-[green]
#
# Unspecified Error
# 30527
# 19
# (30527, 19): [leaves]-[]-[green]
#
# Error: [leaves]-[]-[green]
#
# Unspecified Error
# 30527
# 20
# (30527, 20): [leaves]-[]-[green]
#
# Error: [leaves]-[]-[green]
#
# Unspecified Error
# 30527
# 21
# (30527, 21): [leaves]-[]-[green]
#
# Error: [leaves]-[]-[green]
#
# Unspecified Error
# 30527
# 22
# (30527, 22): [leaves]-[]-[green]
#
# Error: [leaves]-[]-[green]
#
# Unspecified Error
# 30527
# 23
# (30527, 23): [leaves]-[]-[green]
#
# Error: [leaves]-[]-[green]
#
# Unspecified Error
# 30527
# 24
# (30527, 24): [leaves]-[]-[green]
#
# Error: [leaves]-[]-[green]
#
# Unspecified Error
# 30527
# 25
# (30527, 25): [leaves]-[]-[green]
#
# Error: [leaves]-[]-[green]
#
# Unspecified Error
# 30791
# 28
# (30791, 28): [this]-[]-[floor]
#
# Error: [this]-[]-[floor]
#
# Unspecified Error
# 30791
# 29
# (30791, 29): [this]-[]-[sky]
#
# Error: [this]-[]-[sky]
#
# Unspecified Error
# 30942
# 9
# (30942, 9): [hot dog]-[]-[cooked]
#
# Error: [hot dog]-[]-[cooked]
#
# Unspecified Error
# 31201
# 18
# (31201, 18): [wall]-[]-[stone]
#
# Error: [wall]-[]-[stone]
#
# Unspecified Error
# 31747
# 17
# (31747, 17): [snow]-[]-[white]
#
# Error: [snow]-[]-[white]
#
# Unspecified Error
# 31747
# 18
# (31747, 18): [snow]-[]-[white]
#
# Error: [snow]-[]-[white]
#
# Unspecified Error
# 31747
# 19
# (31747, 19): [snow]-[]-[white]
#
# Error: [snow]-[]-[white]
#
# Unspecified Error
# 31747
# 20
# (31747, 20): [snow]-[]-[white]
#
# Error: [snow]-[]-[white]
#
# Unspecified Error
# 31747
# 21
# (31747, 21): [snow]-[]-[white]
#
# Error: [snow]-[]-[white]
#
# Unspecified Error
# 31747
# 22
# (31747, 22): [snow]-[]-[white]
#
# Error: [snow]-[]-[white]
#
# Unspecified Error
# 31843
# 17
# (31843, 17): [bottle]-[]-[wine]
#
# Error: [bottle]-[]-[wine]
#
# Unspecified Error
# 31947
# 2
# (31947, 2): [girl]-[]-[barefoot]
#
# Error: [girl]-[]-[barefoot]
#
# Unspecified Error
# 31947
# 3
# (31947, 3): [floor]-[]-[hardwood]
#
# Error: [floor]-[]-[hardwood]
#
# Unspecified Error
# 32712
# 8
# (32712, 8): [man]-[]-[kiteboarding]
#
# Error: [man]-[]-[kiteboarding]
#
# Unspecified Error
# 32712
# 12
# (32712, 12): [man]-[]-[windsurfing]
#
# Error: [man]-[]-[windsurfing]
#
# Unspecified Error
# 32751
# 12
# (32751, 12): [lawn]-[]-[green]
#
# Error: [lawn]-[]-[green]
#
# Unspecified Error
# 32751
# 13
# (32751, 13): [lawn]-[]-[brown]
#
# Error: [lawn]-[]-[brown]
#
# Unspecified Error
# 32751
# 14
# (32751, 14): [collar]-[]-[black]
#
# Error: [collar]-[]-[black]
#
# Unspecified Error
# 32751
# 15
# (32751, 15): [ear]-[]-[upwards]
#
# Error: [ear]-[]-[upwards]
#
# Unspecified Error
# 32751
# 16
# (32751, 16): [ear]-[]-[upwards]
#
# Error: [ear]-[]-[upwards]
#
# Unspecified Error
# 32751
# 17
# (32751, 17): [dog]-[]-[white]
#
# Error: [dog]-[]-[white]
#
# Unspecified Error
# 32751
# 18
# (32751, 18): [ear]-[]-[brown]
#
# Error: [ear]-[]-[brown]
#
# Unspecified Error
# 32751
# 19
# (32751, 19): [ear]-[]-[brown]
#
# Error: [ear]-[]-[brown]
#
# Unspecified Error
# 32751
# 24
# (32751, 24): [book]-[]-[open]
#
# Error: [book]-[]-[open]
#
# Unspecified Error
# 32751
# 30
# (32751, 30): [shrubbery]-[]-[green]
#
# Error: [shrubbery]-[]-[green]
#
# Unspecified Error
# 32751
# 37
# (32751, 37): [collar]-[]-[black]
#
# Error: [collar]-[]-[black]
#
# Unspecified Error
# 32751
# 42
# (32751, 42): [ear]-[]-[brown]
#
# Error: [ear]-[]-[brown]
#
# Unspecified Error
# 32751
# 43
# (32751, 43): [ear]-[]-[brown]
#
# Error: [ear]-[]-[brown]
#
# Unspecified Error
# 32751
# 48
# (32751, 48): [plant]-[]-[leafy]
#
# Error: [plant]-[]-[leafy]
#
# Unspecified Error
# 32751
# 50
# (32751, 50): [collar]-[]-[black]
#
# Error: [collar]-[]-[black]
#
# Unspecified Error
# 32751
# 52
# (32751, 52): [concrete]-[]-[tan]
#
# Error: [concrete]-[]-[tan]
#
# Unspecified Error
# 32751
# 55
# (32751, 55): [leg]-[]-[white]
#
# Error: [leg]-[]-[white]
#
# Unspecified Error
# 32751
# 56
# (32751, 56): [leg]-[]-[white]
#
# Error: [leg]-[]-[white]
#
# Unspecified Error
# 32751
# 58
# (32751, 58): [dog]-[]-[up]
#
# Error: [dog]-[]-[up]
#
# Unspecified Error
# 32751
# 59
# (32751, 59): [plant]-[]-[large]
#
# Error: [plant]-[]-[large]
#
# Unspecified Error
# 32751
# 60
# (32751, 60): [plant]-[]-[green]
#
# Error: [plant]-[]-[green]
#
# Unspecified Error
# 33275
# 26
# (33275, 26): [court]-[]-[grass]
#
# Error: [court]-[]-[grass]
#
# Unspecified Error
# 33729
# 16
# (33729, 16): [cape]-[]-[santa cape]
#
# Error: [cape]-[]-[santa cape]
#
# Unspecified Error
# 33990
# 4
# (33990, 4): [color]-[]-[shape]
#
# Error: [color]-[]-[shape]
#
# 35000 images processed, 560064 relationships
# Unspecified Error
# 37005
# 10
# (37005, 10): [black]-[]-[tire]
#
# Error: [black]-[]-[tire]
#
# Unspecified Error
# 37743
# 16
# (37743, 16): [pole]-[]-[cemented]
#
# Error: [pole]-[]-[cemented]
#
# Unspecified Error
# 38245
# 6
# (38245, 6): [umbrella]-[]-[outside]
#
# Error: [umbrella]-[]-[outside]
#
# Unspecified Error
# 38338
# 7
# (38338, 7): [green]-[]-[sign]
#
# Error: [green]-[]-[sign]
#
# 40000 images processed, 641215 relationships
# Unspecified Error
# 40558
# 26
# (40558, 26): [cat]-[]-[sitting]
#
# Error: [cat]-[]-[sitting]
#
# Unspecified Error
# 41371
# 1
# (41371, 1): [crust]-[]-[char]
#
# Error: [crust]-[]-[char]
#
# Unspecified Error
# 41414
# 10
# (41414, 10): [leg]-[]-[raised]
#
# Error: [leg]-[]-[raised]
#
# Unspecified Error
# 41728
# 0
# (41728, 0): [girl]-[]-[sea surfing]
#
# Error: [girl]-[]-[sea surfing]
#
# Unspecified Error
# 41860
# 1
# (41860, 1): [guy]-[]-[bald headed]
#
# Error: [guy]-[]-[bald headed]
#
# 45000 images processed, 730875 relationships
# Unspecified Error
# 47311
# 2
# (47311, 2): [giraffe]-[]-[head]
#
# Error: [giraffe]-[]-[head]
#
# Unspecified Error
# 47311
# 3
# (47311, 3): [giraffe]-[]-[head]
#
# Error: [giraffe]-[]-[head]
#
# Unspecified Error
# 48587
# 6
# (48587, 6): [tie]-[laying]-[on torso]
#
# Error: [tie]-[laying]-[on torso]
#
# 50000 images processed, 817518 relationships
# Unspecified Error
# 51556
# 23
# (51556, 23): [xbox]-[]-[logo]
#
# Error: [xbox]-[]-[logo]
#
# 55000 images processed, 902192 relationships
# Unspecified Error
# 55368
# 11
# (55368, 11): [$]-[ON]-[sign]
#
# Error: [$]-[ON]-[sign]
#
# 60000 images processed, 993181 relationships
# Unspecified Error
# 61727
# 11
# (61727, 11): [$]-[ON]-[sign]
#
# Error: [$]-[ON]-[sign]
#
# Unspecified Error
# 63668
# 26
# (63668, 26): [button]-[has]-[#]
#
# Error: [button]-[has]-[#]
#
# 65000 images processed, 1090545 relationships
# Unspecified Error
# 71511
# 7
# (71511, 7): [new jersey]-[]-[banner]
#
# Error: [new jersey]-[]-[banner]
#
# Unspecified Error
# 78736
# 12
# (78736, 12): [patch]-[]-[snow]
#
# Error: [patch]-[]-[snow]
#
# Unspecified Error
# 78736
# 13
# (78736, 13): [patch]-[]-[snow]
#
# Error: [patch]-[]-[snow]
#
# Unspecified Error
# 78736
# 14
# (78736, 14): [patch]-[]-[snow]
#
# Error: [patch]-[]-[snow]
#
# 80000 images processed, 1357197 relationships
# Unspecified Error
# 81192
# 2
# (81192, 2): [bathroom]-[]-[scene]
#
# Error: [bathroom]-[]-[scene]
#
# Unspecified Error
# 81192
# 3
# (81192, 3): [hand]-[]-[persons]
#
# Error: [hand]-[]-[persons]
#
# Unspecified Error
# 81397
# 1
# (81397, 1): [cresting wave]-[]-[breaking]
#
# Error: [cresting wave]-[]-[breaking]
#
# Unspecified Error
# 81499
# 22
# (81499, 22): [is]-[]-[snow]
#
# Error: [is]-[]-[snow]
#
# Unspecified Error
# 81833
# 36
# (81833, 36): [painting]-[]-[farm animals]
#
# Error: [painting]-[]-[farm animals]
#
# Unspecified Error
# 82064
# 46
# (82064, 46): [rain drop]-[]-[falling]
#
# Error: [rain drop]-[]-[falling]
#
# Unspecified Error
# 82064
# 47
# (82064, 47): [rain drop]-[]-[falling]
#
# Error: [rain drop]-[]-[falling]
#
# Unspecified Error
# 82064
# 48
# (82064, 48): [rain drop]-[]-[falling]
#
# Error: [rain drop]-[]-[falling]
#
# Unspecified Error
# 82064
# 49
# (82064, 49): [rain drop]-[]-[falling]
#
# Error: [rain drop]-[]-[falling]
#
# Unspecified Error
# 82064
# 50
# (82064, 50): [rain drop]-[]-[falling]
#
# Error: [rain drop]-[]-[falling]
#
# Unspecified Error
# 82064
# 51
# (82064, 51): [rain drop]-[]-[falling]
#
# Error: [rain drop]-[]-[falling]
#
# Unspecified Error
# 82064
# 52
# (82064, 52): [rain drop]-[]-[falling]
#
# Error: [rain drop]-[]-[falling]
#
# Unspecified Error
# 82064
# 53
# (82064, 53): [rain drop]-[]-[falling]
#
# Error: [rain drop]-[]-[falling]
#
# Unspecified Error
# 82092
# 12
# (82092, 12): [child]-[]-[standing]
#
# Error: [child]-[]-[standing]
#
# Unspecified Error
# 82092
# 13
# (82092, 13): [child]-[]-[skiing]
#
# Error: [child]-[]-[skiing]
#
# Unspecified Error
# 82093
# 22
# (82093, 22): [train]-[]-[moving]
#
# Error: [train]-[]-[moving]
#
# Unspecified Error
# 82125
# 17
# (82125, 17): [this]-[]-[light]
#
# Error: [this]-[]-[light]
#
# Unspecified Error
# 82125
# 27
# (82125, 27): [formation]-[]-[interesting]
#
# Error: [formation]-[]-[interesting]
#
# Unspecified Error
# 82133
# 28
# (82133, 28): [boy]-[]-[surfing]
#
# Error: [boy]-[]-[surfing]
#
# Unspecified Error
# 82133
# 30
# (82133, 30): [wave]-[]-[splashing]
#
# Error: [wave]-[]-[splashing]
#
# Unspecified Error
# 82133
# 31
# (82133, 31): [wave]-[]-[splashing]
#
# Error: [wave]-[]-[splashing]
#
# Unspecified Error
# 82163
# 10
# (82163, 10): [train]-[]-[stop]
#
# Error: [train]-[]-[stop]
#
# Unspecified Error
# 82179
# 28
# (82179, 28): [bear]-[]-[moving]
#
# Error: [bear]-[]-[moving]
#
# Unspecified Error
# 82212
# 2
# (82212, 2): [page]-[]-[mahmood's den]
#
# Error: [page]-[]-[mahmood's den]
#
# Unspecified Error
# 82548
# 20
# (82548, 20): [train]-[]-[parked]
#
# Error: [train]-[]-[parked]
#
# Unspecified Error
# 82624
# 31
# (82624, 31): [zebra]-[]-[eating]
#
# Error: [zebra]-[]-[eating]
#
# Unspecified Error
# 82624
# 32
# (82624, 32): [zebra]-[]-[eating]
#
# Error: [zebra]-[]-[eating]
#
# Unspecified Error
# 82624
# 33
# (82624, 33): [zebra]-[]-[eating]
#
# Error: [zebra]-[]-[eating]
#
# Unspecified Error
# 82624
# 34
# (82624, 34): [zebra]-[]-[eating]
#
# Error: [zebra]-[]-[eating]
#
# Unspecified Error
# 82624
# 35
# (82624, 35): [zebra]-[]-[eating]
#
# Error: [zebra]-[]-[eating]
#
# Unspecified Error
# 82624
# 36
# (82624, 36): [zebra]-[]-[eating]
#
# Error: [zebra]-[]-[eating]
#
# Unspecified Error
# 82624
# 37
# (82624, 37): [zebra]-[]-[eating]
#
# Error: [zebra]-[]-[eating]
#
# Unspecified Error
# 82624
# 38
# (82624, 38): [zebra]-[]-[eating]
#
# Error: [zebra]-[]-[eating]
#
# Unspecified Error
# 82624
# 39
# (82624, 39): [zebra]-[]-[eating]
#
# Error: [zebra]-[]-[eating]
#
# Unspecified Error
# 82624
# 40
# (82624, 40): [giraffe]-[]-[eating]
#
# Error: [giraffe]-[]-[eating]
#
# Unspecified Error
# 82624
# 41
# (82624, 41): [giraffe]-[]-[eating]
#
# Error: [giraffe]-[]-[eating]
#
# Unspecified Error
# 82624
# 42
# (82624, 42): [giraffe]-[]-[eating]
#
# Error: [giraffe]-[]-[eating]
#
# Unspecified Error
# 82624
# 43
# (82624, 43): [giraffe]-[]-[eating]
#
# Error: [giraffe]-[]-[eating]
#
# Unspecified Error
# 82624
# 44
# (82624, 44): [giraffe]-[]-[eating]
#
# Error: [giraffe]-[]-[eating]
#
# Unspecified Error
# 82624
# 45
# (82624, 45): [giraffe]-[]-[eating]
#
# Error: [giraffe]-[]-[eating]
#
# Unspecified Error
# 82624
# 46
# (82624, 46): [giraffe]-[]-[eating]
#
# Error: [giraffe]-[]-[eating]
#
# Unspecified Error
# 82624
# 47
# (82624, 47): [giraffe]-[]-[eating]
#
# Error: [giraffe]-[]-[eating]
#
# Unspecified Error
# 82624
# 48
# (82624, 48): [giraffe]-[]-[eating]
#
# Error: [giraffe]-[]-[eating]
#
# Unspecified Error
# 82624
# 49
# (82624, 49): [giraffe]-[]-[eating]
#
# Error: [giraffe]-[]-[eating]
#
# Unspecified Error
# 83371
# 32
# (83371, 32): [tail]-[]-[bird]
#
# Error: [tail]-[]-[bird]
#
# Unspecified Error
# 83488
# 20
# (83488, 20): [young man]-[]-[skateboarding]
#
# Error: [young man]-[]-[skateboarding]
#
# Unspecified Error
# 83633
# 7
# (83633, 7): [this]-[]-[airplane]
#
# Error: [this]-[]-[airplane]
#
# Unspecified Error
# 84258
# 24
# (84258, 24): [man]-[]-[skiing]
#
# Error: [man]-[]-[skiing]
#
# Unspecified Error
# 84259
# 27
# (84259, 27): [plane]-[]-[remote control]
#
# Error: [plane]-[]-[remote control]
#
# Unspecified Error
# 84588
# 23
# (84588, 23): [this]-[]-[kitchen]
#
# Error: [this]-[]-[kitchen]
#
# Unspecified Error
# 85456
# 17
# (85456, 17): [snow]-[]-[white]
#
# Error: [snow]-[]-[white]
#
# Unspecified Error
# 85946
# 1
# (85946, 1): [this]-[]-[scene]
#
# Error: [this]-[]-[scene]
#
# Unspecified Error
# 85946
# 2
# (85946, 2): [this]-[]-[scene]
#
# Error: [this]-[]-[scene]
#
# Unspecified Error
# 86514
# 6
# (86514, 6): [bear]-[]-[walking]
#
# Error: [bear]-[]-[walking]
#
# Unspecified Error
# 86514
# 7
# (86514, 7): [bear]-[]-[walking]
#
# Error: [bear]-[]-[walking]
#
# Unspecified Error
# 87152
# 8
# (87152, 8): [roof]-[]-[doomed]
#
# Error: [roof]-[]-[doomed]
#
# Unspecified Error
# 88073
# 2
# (88073, 2): [sky]-[]-[cloudy]
#
# Error: [sky]-[]-[cloudy]
#
# Unspecified Error
# 88378
# 2
# (88378, 2): [scene]-[]-[inside]
#
# Error: [scene]-[]-[inside]
#
# Unspecified Error
# 88967
# 19
# (88967, 19): [elephant]-[]-[walking]
#
# Error: [elephant]-[]-[walking]
#
# Unspecified Error
# 89488
# 2
# (89488, 2): [sidewalk]-[]-[bricks]
#
# Error: [sidewalk]-[]-[bricks]
#
# Unspecified Error
# 89490
# 0
# (89490, 0): [scene]-[]-[outside]
#
# Error: [scene]-[]-[outside]
#
# 90000 images processed, 1474696 relationships
# 95000 images processed, 1546122 relationships
# 100000 images processed, 1624710 relationships
# Unspecified Error
# 100100
# 39
# (100100, 39): [suitcase]-[]-[bottle]
#
# Error: [suitcase]-[]-[bottle]
#
# Unspecified Error
# 103003
# 0
# (103003, 0): [airplane]-[]-[flying]
#
# Error: [airplane]-[]-[flying]
#
# 105000 images processed, 1717812 relationships
# Unspecified Error
# 106714
# 5
# (106714, 5): [nail]-[]-[man]
#
# Error: [nail]-[]-[man]
#
# Currently, we have 1758859 relationship tuples and 86179 images
# Spelling error: 66514
# Length matching error: 5467

# %% [markdown]
# # Filtering the Top-50 predicate and Top-150 object categories

# %%
def get_object_predicate_list(relationships):
    object_list = set()
    predicate_list = set()
    for im_id in relationships:
        for r_id, relationship_item in enumerate(relationships[im_id]['relationships']):
            object_list.add(relationship_item['subject'])
            object_list.add(relationship_item['object'])
            predicate_list.add(relationship_item['predicate'])
            
    print "Object classes: %d\nPredicate classes: %d\n" % (len(object_list), len(predicate_list))
    return object_list, predicate_list
    
def object_predicate_categories_count(relationships):
    object_list, predicate_list = get_object_predicate_list(relationships)
    freq_obj = {x:0 for x in object_list}
    freq_pred = {x:0 for x in predicate_list}
    for im_id in relationships:
        for r_id, relationship_item in enumerate(relationships[im_id]['relationships']):
            temp_sub = relationship_item['subject']
            temp_obj = relationship_item['object']
            temp_predicate = relationship_item['predicate']
            freq_obj[temp_sub] += 1    
            freq_obj[temp_obj] += 1
            freq_pred[temp_predicate] += 1    
    return freq_obj, freq_pred

def filter_categories(original_relationships, top_n_obj=150, top_n_pred=50):
    import copy
    original_im_num = len(original_relationships.keys())
    relationships = copy.deepcopy(original_relationships)
    freq_obj, freq_pred = object_predicate_categories_count(relationships)
    import operator
    sorted_obj = sorted(freq_obj.items(), key=operator.itemgetter(1), reverse=True)
    sorted_pred = sorted(freq_pred.items(), key=operator.itemgetter(1), reverse=True)
    selected_obj = set(x[0] for x in sorted_obj[:top_n_obj])
    selected_pred = set(x[0] for x in sorted_pred[:top_n_pred])
    for im_id in relationships.keys():
        for relationship_item in list(relationships[im_id]['relationships']):
            temp_sub = relationship_item['subject']
            temp_obj = relationship_item['object']
            temp_predicate = relationship_item['predicate']
            if temp_sub not in selected_obj or temp_obj not in selected_obj or temp_predicate not in selected_pred:
                relationships[im_id]['relationships'].remove(relationship_item)
        if len(relationships[im_id]['relationships']) < 5:
            relationships.pop(im_id)
    print "%d images left(%d/%d removed)" % \
        (len(relationships.keys()), original_im_num - len(relationships.keys()), original_im_num)
         
    return relationships, selected_obj, selected_pred

def count_instance_num(relationships):
    instance_counter = 0
    for im_id in relationships.keys():
        instance_counter+= len(relationships[im_id]['relationships'])  
    return instance_counter

def im_with_N_more_instances(relationships, N = 15):
    id_list = []
    for im_id in relationships.keys():
        if len(relationships[im_id]['relationships']) >= N:
            id_list.append(im_id)
    print "%d images with more than %d instances" % (len(id_list), N)
    return id_list

def select_top_N_ims(relationships, N):
    import operator
    instance_num = [(x, len(relationships[x]['relationships'])) for x in relationships]
    id_list = sorted(instance_num, key=operator.itemgetter(1), reverse=True)
    assert N<=len(id_list), "Select %d images from %d" % (N, len(id_list))
    return [x[0] for x in id_list[:N]]

# %% [markdown]
# ## Now filter out the long-tail categories

# %%
relationships, selected_obj, selected_pred = filter_categories(imported_data.data)
freq_obj, freq_pred = object_predicate_categories_count(relationships)
# Out:
# Object classes: 41984
# Predicate classes: 24126
#
# 56164 images left(30015/86179 removed)
# Object classes: 150
# Predicate classes: 50

# %%
def count_training_weight(relationships):
    import numpy as np
    freq_obj, freq_pred = object_predicate_categories_count(relationships)
    total_counter_obj = 0
    total_counter_pred = 0
    inverse_weight_pred = {}
    inverse_weight_obj = {}
    print '========= counting result ========'
    print '------------ object --------------'
    for c in freq_obj:
        print '[{}]: {}'.format(c, freq_obj[c])
        total_counter_obj += freq_obj[c]
    print '----------- predicate ------------'
    for c in freq_pred:
        print '[{}]: {}'.format(c, freq_pred[c])
        total_counter_pred+= freq_pred[c]
    print '========= counting result ========'
    print '------------ object --------------'
    for c in freq_obj:
        print '[{}]: {}'.format(c, np.sqrt(total_counter_obj / freq_obj[c] / 150.))
        inverse_weight_obj[c] = np.sqrt(total_counter_obj / freq_obj[c] / 150.)
    print '----------- predicate ------------'
    for c in freq_pred:
        print '[{}]: {}'.format(c, np.sqrt(total_counter_pred / freq_pred[c]  / 50.))
        inverse_weight_pred[c] = np.sqrt(total_counter_pred / freq_pred[c] / 50.)
    
    return inverse_weight_obj, inverse_weight_pred
    
def output_inverse_weight(filename, inverse_weight_obj, inverse_weight_pred):
    import json
    inverse_weight = {'object': inverse_weight_obj, 'predicate': inverse_weight_pred}
    with open(filename, 'w') as fp:
        json.dump(inverse_weight, fp)

# %% [markdown]
# ## Partition dataset
#
# 1. subsample 25000 images for testing;
# 2. remaining 70999 images for training;
# 3. Different training/testing settings
#     - original dataset: 70999 images for training and 25000 images for testing
#     - Small dataset: 15000 images for training and 5000 for testing
#     - Fat Dataset： 15000 images with 15+ instances for training and 5000 for testing

# %%
import random
im_list_full = relationships.keys()
random.shuffle(im_list_full)
training_list = im_list_full[:-10000]
testing_list = im_list_full[-10000:]
training_set = {x:relationships[x] for x in training_list}
testing_set = {x:relationships[x] for x in testing_list}
training_small_list = training_list[:15000]
testing_small_list = testing_list[:5000]
training_fat_list = select_top_N_ims(training_set, 15000)

# %%
relationships[2282]
# Out:
# {'height': 600,
#  'image_id': 2283,
#  'path': '2283.jpg',
#  'regions': [{'box': (322, 237, 393, 321),
#    'phrase': ['tail', 'of', 'the', 'squirrel']},
#   {'box': (620, 2, 721, 215),
#    'phrase': ['a', 'black', 'post', 'on', 'the', 'sidewalk']},
#   {'box': (6, 4, 102, 365), 'phrase': ['trunk', 'of', 'a', 'tree']},
#   {'box': (50, 10, 322, 77),
#    'phrase': ['wooden', 'benches', 'in', 'a', 'park']},
#   {'box': (368, 8, 440, 167),
#    'phrase': ['a', 'black', 'post', 'to', 'the', 'fence']},
#   {'box': (620, 133, 705, 220), 'phrase': ['base', 'of', 'a', 'post']},
#   {'box': (104, 372, 533, 545), 'phrase': ['grass', 'that', 'is', 'lush']},
#   {'box': (0, 0, 73, 320), 'phrase': ['bark', 'on', 'tree', 'trunk']},
#   {'box': (5, 178, 793, 596),
#    'phrase': ['green', 'grass', 'with', 'bare', 'patches']},
#   {'box': (623, 2, 707, 198), 'phrase': ['base', 'of', 'lamp', 'post']},
#   {'box': (42, 3, 535, 71), 'phrase': ['row', 'of', 'park', 'benches']},
#   {'box': (337, 3, 425, 87),
#    'phrase': ['legs', 'of', 'two', 'seated', 'people']},
#   {'box': (37, 14, 792, 194), 'phrase': ['wire', 'fence', 'with', 'poles']},
#   {'box': (495, 13, 534, 61), 'phrase': ['curved', 'arm', 'of', 'bench']},
#   {'box': (46, 68, 797, 199),
#    'phrase': ['walkway', 'with', 'light', 'and', 'shadow']},
#   {'box': (344, 276, 481, 315),
#    'phrase': ['a', 'brown', 'squirrel', 'on', 'the', 'grass']},
#   {'box': (92, 141, 222, 178),
#    'phrase': ['brown', 'leaves', 'on', 'the', 'ground']},
#   {'box': (342, 7, 418, 78),
#    'phrase': ['a', 'person', 'sitting', 'on', 'a', 'bench']},
#   {'box': (434, 4, 489, 48),
#    'phrase': ['a', 'white', 'plastic', 'bag', 'on', 'a', 'bench']},
#   {'box': (42, 7, 354, 57),
#    'phrase': ['two', 'wood', 'and', 'metal', 'benches']},
#   {'box': (0, 0, 81, 327), 'phrase': ['tree', 'growing', 'in', 'the', 'park']},
#   {'box': (625, 2, 707, 204), 'phrase': ['lamp', 'post', 'in', 'the', 'park']},
#   {'box': (321, 1, 445, 89), 'phrase': ['man', 'and', 'woman', 'on', 'bench']},
#   {'box': (439, 7, 476, 48), 'phrase': ['food', 'on', 'top', 'of', 'bench']},
#   {'box': (3, 166, 794, 594),
#    'phrase': ['grassy', 'part', 'of', 'the', 'park']},
#   {'box': (45, 65, 792, 200),
#    'phrase': ['walking', 'path', 'next', 'to', 'park']},
#   {'box': (106, 0, 204, 75), 'phrase': ['an', 'empty', 'park', 'bench']},
#   {'box': (37, 0, 797, 204),
#    'phrase': ['fence', 'separating', 'grass', 'and', 'path']},
#   {'box': (343, 258, 479, 333), 'phrase': ['brown', 'furry', 'squirrel']},
#   {'box': (631, 6, 706, 203), 'phrase': ['black', 'painted', 'lamp', 'post']},
#   {'box': (340, 1, 428, 89), 'phrase': ['person', 'sitting', 'on', 'bench']},
#   {'box': (2, 176, 797, 597),
#    'phrase': ['green', 'grassy', 'area', 'in', 'park']},
#   {'box': (0, 0, 74, 325), 'phrase': ['brown', 'trunk', 'of', 'tree']},
#   {'box': (407, 1, 545, 82),
#    'phrase': ['wooden', 'and', 'metal', 'park', 'bench']},
#   {'box': (224, 483, 281, 531), 'phrase': ['rocks', 'in', 'the', 'grass']},
#   {'box': (342, 256, 482, 327),
#    'phrase': ['a', 'squirrel', 'in', 'the', 'grass']},
#   {'box': (13, 143, 790, 591),
#    'phrase': ['the', 'green', 'grass', 'on', 'the', 'ground']},
#   {'box': (0, 6, 98, 330), 'phrase': ['the', 'trunk', 'of', 'the', 'tree']},
#   {'box': (617, 0, 714, 216),
#    'phrase': ['the', 'bottom', 'of', 'the', 'post']},
#   {'box': (341, 251, 394, 312), 'phrase': ['the', 'squirrels', 'tail']},
#   {'box': (29, 0, 546, 106), 'phrase': ['several', 'park', 'benches']},
#   {'box': (348, 261, 473, 328),
#    'phrase': ['brown', 'squirrel', 'in', 'the', 'grass']},
#   {'box': (42, 17, 796, 203), 'phrase': ['black', 'mesh', 'fence']},
#   {'box': (415, 3, 540, 88),
#    'phrase': ['white', 'plastic', 'bag', 'on', 'a', 'bench']},
#   {'box': (4, 169, 796, 596),
#    'phrase': ['green', 'grass', 'covered', 'ground']}],
#  'relationships': [{'obj_box': (200, 220, 539, 417),
#    'object': 'grass',
#    'predicate': 'in',
#    'sub_box': (498, 213, 726, 419),
#    'subject': 'grass'},
#   {'obj_box': (38, 337, 774, 568),
#    'object': 'ground',
#    'predicate': 'on',
#    'sub_box': (541, 249, 748, 383),
#    'subject': 'grass'},
#   {'obj_box': (0, 223, 94, 324),
#    'object': 'trunk',
#    'predicate': u'have',
#    'sub_box': (1, 3, 79, 332),
#    'subject': 'tree'},
#   {'obj_box': (350, 71, 413, 88),
#    'object': u'shoe',
#    'predicate': u'wear',
#    'sub_box': (353, 2, 432, 91),
#    'subject': 'person'},
#   {'obj_box': (417, 42, 536, 83),
#    'object': 'bench',
#    'predicate': 'on_a',
#    'sub_box': (437, 6, 476, 42),
#    'subject': 'bag'},
#   {'obj_box': (6, 326, 787, 585),
#    'object': 'ground',
#    'predicate': u'cover',
#    'sub_box': (549, 238, 775, 388),
#    'subject': 'grass'}],
#  'width': 800}

# %% [markdown]
# ## Loading region description dataset

# %%
def object_matching(objects, rel):
    obj_item = {}
    obj_item['class'] = rel['object']
    obj_item['box'] = rel['obj_box']
    sub_item = {}
    sub_item['class'] = rel['subject']
    sub_item['box'] = rel['sub_box']
    
    obj_id = -1
    sub_id = -1
    
    for idx, obj in enumerate(objects):
        if obj_item == obj:
            obj_id = idx
        if sub_item == obj:
            sub_id = idx
    if sub_id < 0 or obj_id < 0:
        raise Exception('Object Matching Error!')
        
    return sub_id, obj_id

def check_is_included(objects, obj_item):
    for ex_obj in objects:
        if ex_obj == obj_item:
            return True
    return False

def dataset_setup(id_list, relationships):
    import copy
    import string
    import nltk
    replace_punctuation = string.maketrans(string.punctuation, ' '*len(string.punctuation))
    dataset = []
    ignore_counter_out = 0
    ignore_counter_small = 0
    ignore_counter_short = 0
    ignore_counter_object_small = 0
    region_counter = 0
    region_min_num = 1000
    rel_counter = 0
    for im_id in id_list:
        im_item = {}
        im_item['id'] = im_id
        im_item['path'] = relationships[im_id]['path']
        im_item['height'] = relationships[im_id]['height']
        im_item['width'] = relationships[im_id]['width']
        regions = relationships[im_id]['regions']
        objects = []
        relationships_new = []
        if len(regions) < region_min_num:
            region_min_num = len(regions)
        for rel in relationships[im_id]['relationships']:
            obj_item = {}
            obj_item['class'] = rel['object']
            obj_item['box'] = rel['obj_box']
            sub_item = {}
            sub_item['class'] = rel['subject']
            sub_item['box'] = rel['sub_box']
            rel_item = {}
            if not check_is_included(objects, obj_item):
                objects.append(obj_item)
            if not check_is_included(objects, sub_item):
                objects.append(sub_item)    
            rel_item['sub_id'], rel_item['obj_id'] = object_matching(objects, rel)
            rel_item['predicate'] = rel['predicate']
            rel_counter+=1
            relationships_new.append(rel_item)
        if len(relationships_new) >= 5 and len(regions) >= 20 and len(regions) <= 50:
            im_item['regions'] = regions
            im_item['objects'] = objects
            im_item['relationships'] = relationships_new
            dataset.append(im_item)
        else:
            print 'Image ignored: relationship: {}, regions: {}'.format(
                len(relationships_new), len(regions))
            
    print 'Total: %d images (%d filtered)' % (len(dataset), len(id_list) - len(dataset))
    return dataset

def output_dataset(dataset, filename):
    import json
    with open(filename, 'w') as fp:
        json.dump(dataset, fp)
    print "Done output dataset: "+filename
    
def output_category_list(selected_obj, selected_pred, filename):
    categories = {'object': list(selected_obj), 'predicate': list(selected_pred)}
    
    import json
    with open(filename, 'w') as fp:
        json.dump(categories, fp)
    print "Done output category list: " + filename

# %%
training_small_set = dataset_setup(training_small_list, relationships)
testing_small_set = dataset_setup(testing_small_list, relationships)
training_set = dataset_setup(training_list, relationships)
testing_set = dataset_setup(testing_list, relationships)
training_fat_set = dataset_setup(training_fat_list, relationships)
# Out:
# Total: 15000 images (0 filtered)
# Total: 5000 images (0 filtered)
# Total: 46164 images (0 filtered)
# Total: 10000 images (0 filtered)
# Total: 15000 images (0 filtered)

# %%
output_dir = 'output/top_150_50_full/'
output_dataset(training_set, output_dir+'train.json')
output_dataset(testing_set, output_dir+'test.json')
output_dataset(training_small_set, output_dir+'train_small.json')
output_dataset(testing_small_set, output_dir+'test_small.json')
output_dataset(training_fat_set, output_dir+'train_fat.json')
output_category_list(selected_obj, selected_pred, output_dir + 'categories.json')
inverse_weight_obj, inverse_weight_pred = count_training_weight(relationships)
output_inverse_weight(output_dir + 'inverse_weight.json', inverse_weight_obj, inverse_weight_pred)
# Out:
# Done output dataset: output/top_150_50_full/train.json
# Done output dataset: output/top_150_50_full/test.json
# Done output dataset: output/top_150_50_full/train_small.json
# Done output dataset: output/top_150_50_full/test_small.json
# Done output dataset: output/top_150_50_full/train_fat.json
# Done output category list: output/top_150_50_full/categories.json
# Object classes: 150
# Predicate classes: 50
#
# ========= counting result ========
# ------------ object --------------
# [bush]: 3591
# [kite]: 3890
# [pant]: 8796
# [on_side_of]: 1.88148877222
# [attach_to]: 2.5495097568
# [of]: 0.529150262213
# [be_in]: 2.4819347292
# [cover]: 2.54165300543
# [hang_from]: 5.96992462264
# [below]: 3.12729915422
# [sit_in]: 3.07571129985
# [of_a]: 1.45602197786
# [stand_in]: 2.06881608656
# [inside_of]: 4.49221548904

# %% [markdown]
# ## Buildup dictionary for sentences

# %%
# class Dictionary(object):
#     def __init__(self):
#         self.word2idx = {}
#         self.idx2word = []
#         self.word_freq = {}

#     def add_word(self, word):
#         if word not in self.word2idx:
#             self.idx2word.append(word)
#             self.word2idx[word] = len(self.idx2word) - 1
#             self.word_freq[word] = len(s)
#         return self.word2idx[word]

#     def __len__(self):
#         return len(self.idx2word)

# def buildup_dictionary(trainset, testset, filename):
#     import json
#     dictionary = Dictionary()
#     print('First, training set...')
#     for im in trainset:
#         for region in im['regions']:
#             words = region['phrase'].split() + ['<eos>']
#             for word in words:
#                     dictionary.add_word(word)
#     print('Then, testing set...')
#     for im in testset:
#         for region in im['regions']:
#             words = region['phrase'].split() + ['<eos>']
#             for word in words:
#                     dictionary.add_word(word)
                    
#     print 'Dictionary has %d words' % len(dictionary.idx2word)
#     dict_ = {'word2idx': dictionary.word2idx, 'idx2word': dictionary.idx2word}
#     with open(filename, 'w') as fp:
#         json.dump(dict_, fp)
#     print "Done output category list: " + filename
#     return dict_


def buildup_dictionary(trainset, testset, filename, freq_thres=10):
    import json
    import nltk
    import itertools
    
    descriptions = []
    for im in trainset:
        for region in im['regions']:
            descriptions.append(region['phrase'])
    for im in testset:
        for region in im['regions']:
            descriptions.append(region['phrase'])
    print 'descriptions.len', len(descriptions)
    word_freq = nltk.FreqDist(itertools.chain(*descriptions))
    vocab = [word for word in word_freq.keys() if word_freq[word] > freq_thres]
    index_to_word = vocab
    word_to_index = dict([(w,i) for i,w in enumerate(index_to_word)])
    print 'Vocabulary size: {}'.format(len(vocab))
    dict_ = {'word2idx': word_to_index, 'idx2word': index_to_word}
    with open(filename, 'w') as fp:
        json.dump(dict_, fp)
    print "Done output category list: " + filename
    return dict_, word_freq

# %%
dictionary, freq = buildup_dictionary(training_set, testing_set, output_dir+'dict.json', freq_thres=10)
# Out:
# descriptions.len 2001747
# Vocabulary size: 8380
# Done output category list: output/top_150_50_full/dict.json

# %%
import json
import numpy as np
import torch
data = json.load(open(output_dir+'inverse_weight.json'))
weight = torch.zeros(151)
for idx, k in enumerate(data['object'].keys()):
    weight[idx + 1] = data['object'][k]

# %%
print data['object'].keys()
# Out:
# [u'kite', u'pant', u'laptop', u'paper', u'motorcycle', u'chair', u'ground', u'tire', u'cup', u'sky', u'bench', u'tail', u'bike', u'board', u'orange', u'hat', u'skier', u'plate', u'woman', u'handle', u'branch', u'food', u'bear', u'vase', u'giraffe', u'background', u'desk', u'foot', u'shadow', u'lady', u'glove', u'bag', u'sand', u'nose', u'rock', u'tower', u'shoe', u'fence', u'people', u'house', u'sign', u'hair', u'street', u'bed', u'mirror', u'racket', u'logo', u'girl', u'arm', u'flower', u'leaf', u'clock', u'dirt', u'hill', u'bird', u'umbrella', u'leg', u'reflection',