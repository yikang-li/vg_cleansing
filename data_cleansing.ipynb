# %% [markdown]
# # Visual Genome Dataset Cleansing
#
# Loading dataset
# -----------
#
# - To read data from the JSON file and remove the annotations with wrong spelling.

# %%
import numpy as np
import math
import sys

sys.path.append('./python_code')
import preprocessing_data as imported_data
# Out:
# image data length: 108077
# relationship data length: 108077
# 0 images processed, 41 relationships
# Unspecified Error
# 2112
# 21
# (2112, 21): [block]-[]-[rug]
#
# Error: [block]-[]-[rug]
#
# Unspecified Error
# 2112
# 22
# (2112, 22): [block]-[]-[rug]
#
# Error: [block]-[]-[rug]
#
# Unspecified Error
# 2112
# 23
# (2112, 23): [block]-[]-[rug]
#
# Error: [block]-[]-[rug]
#
# Unspecified Error
# 3780
# 53
# (3780, 53): [chair]-[]-[outside]
#
# Error: [chair]-[]-[outside]
#
# 5000 images processed, 91320 relationships
# Unspecified Error
# 6768
# 22
# (6768, 22): [sky]-[]-[above]
#
# Error: [sky]-[]-[above]
#
# Unspecified Error
# 6839
# 15
# (6839, 15): [is]-[]-[sidewalk]
#
# Error: [is]-[]-[sidewalk]
#
# Unspecified Error
# 6993
# 10
# (6993, 10): [laptop]-[]-[open]
#
# Error: [laptop]-[]-[open]
#
# Unspecified Error
# 7023
# 21
# (7023, 21): [box]-[]-[pizza hut]
#
# Error: [box]-[]-[pizza hut]
#
# Unspecified Error
# 7024
# 7
# (7024, 7): [alcove]-[]-[open]
#
# Error: [alcove]-[]-[open]
#
# Unspecified Error
# 9015
# 31
# (9015, 31): [girl]-[]-[outside]
#
# Error: [girl]-[]-[outside]
#
# Unspecified Error
# 9015
# 33
# (9015, 33): [girl]-[]-[outside]
#
# Error: [girl]-[]-[outside]
#
# Unspecified Error
# 9782
# 4
# (9782, 4): [man]-[]-[sleeping]
#
# Error: [man]-[]-[sleeping]
#
# Unspecified Error
# 9830
# 7
# (9830, 7): [view]-[]-[shadow]
#
# Error: [view]-[]-[shadow]
#
# Unspecified Error
# 9830
# 8
# (9830, 8): [view]-[]-[building]
#
# Error: [view]-[]-[building]
#
# Unspecified Error
# 9830
# 9
# (9830, 9): [trees]-[]-[view]
#
# Error: [trees]-[]-[view]
#
# Unspecified Error
# 9834
# 27
# (9834, 27): [man]-[]-[bending over]
#
# Error: [man]-[]-[bending over]
#
# 10000 images processed, 166109 relationships
# Unspecified Error
# 14024
# 53
# (14024, 53): [ear]-[]-[side of head]
#
# Error: [ear]-[]-[side of head]
#
# Unspecified Error
# 14024
# 54
# (14024, 54): [ear]-[]-[side of head]
#
# Error: [ear]-[]-[side of head]
#
# 15000 images processed, 308474 relationships
# 20000 images processed, 436376 relationships
# 25000 images processed, 544112 relationships
# Unspecified Error
# 25565
# 36
# (25565, 36): [the]-[]-[sign]
#
# Error: [the]-[]-[sign]
#
# Unspecified Error
# 25597
# 24
# (25597, 24): [number]-[]-[sign]
#
# Error: [number]-[]-[sign]
#
# 30000 images processed, 640403 relationships
# Unspecified Error
# 30436
# 10
# (30436, 10): [mark]-[]-[spotted]
#
# Error: [mark]-[]-[spotted]
#
# Unspecified Error
# 30436
# 11
# (30436, 11): [mark]-[]-[spotted]
#
# Error: [mark]-[]-[spotted]
#
# Unspecified Error
# 30436
# 12
# (30436, 12): [mark]-[]-[spotted]
#
# Error: [mark]-[]-[spotted]
#
# Unspecified Error
# 30436
# 13
# (30436, 13): [mark]-[]-[spotted]
#
# Error: [mark]-[]-[spotted]
#
# Unspecified Error
# 30436
# 14
# (30436, 14): [mark]-[]-[spotted]
#
# Error: [mark]-[]-[spotted]
#
# Unspecified Error
# 30436
# 15
# (30436, 15): [mark]-[]-[spotted]
#
# Error: [mark]-[]-[spotted]
#
# Unspecified Error
# 30436
# 24
# (30436, 24): [mark]-[]-[spotted]
#
# Error: [mark]-[]-[spotted]
#
# Unspecified Error
# 30436
# 25
# (30436, 25): [mark]-[]-[spotted]
#
# Error: [mark]-[]-[spotted]
#
# Unspecified Error
# 30436
# 26
# (30436, 26): [mark]-[]-[spotted]
#
# Error: [mark]-[]-[spotted]
#
# Unspecified Error
# 30436
# 27
# (30436, 27): [mark]-[]-[spotted]
#
# Error: [mark]-[]-[spotted]
#
# Unspecified Error
# 30436
# 28
# (30436, 28): [mark]-[]-[spotted]
#
# Error: [mark]-[]-[spotted]
#
# Unspecified Error
# 30527
# 14
# (30527, 14): [leaves]-[]-[green]
#
# Error: [leaves]-[]-[green]
#
# Unspecified Error
# 30527
# 15
# (30527, 15): [leaves]-[]-[green]
#
# Error: [leaves]-[]-[green]
#
# Unspecified Error
# 30527
# 16
# (30527, 16): [leaves]-[]-[green]
#
# Error: [leaves]-[]-[green]
#
# Unspecified Error
# 30527
# 17
# (30527, 17): [leaves]-[]-[green]
#
# Error: [leaves]-[]-[green]
#
# Unspecified Error
# 30527
# 18
# (30527, 18): [leaves]-[]-[green]
#
# Error: [leaves]-[]-[green]
#
# Unspecified Error
# 30527
# 19
# (30527, 19): [leaves]-[]-[green]
#
# Error: [leaves]-[]-[green]
#
# Unspecified Error
# 30527
# 20
# (30527, 20): [leaves]-[]-[green]
#
# Error: [leaves]-[]-[green]
#
# Unspecified Error
# 30527
# 21
# (30527, 21): [leaves]-[]-[green]
#
# Error: [leaves]-[]-[green]
#
# Unspecified Error
# 30527
# 22
# (30527, 22): [leaves]-[]-[green]
#
# Error: [leaves]-[]-[green]
#
# Unspecified Error
# 30527
# 23
# (30527, 23): [leaves]-[]-[green]
#
# Error: [leaves]-[]-[green]
#
# Unspecified Error
# 30527
# 24
# (30527, 24): [leaves]-[]-[green]
#
# Error: [leaves]-[]-[green]
#
# Unspecified Error
# 30527
# 25
# (30527, 25): [leaves]-[]-[green]
#
# Error: [leaves]-[]-[green]
#
# Unspecified Error
# 30791
# 28
# (30791, 28): [this]-[]-[floor]
#
# Error: [this]-[]-[floor]
#
# Unspecified Error
# 30791
# 29
# (30791, 29): [this]-[]-[sky]
#
# Error: [this]-[]-[sky]
#
# Unspecified Error
# 30942
# 9
# (30942, 9): [hot dog]-[]-[cooked]
#
# Error: [hot dog]-[]-[cooked]
#
# Unspecified Error
# 30961
# 6
# (30961, 6): [giraffe]-[]-[eating]
#
# Error: [giraffe]-[]-[eating]
#
# Unspecified Error
# 30961
# 7
# (30961, 7): [giraffe]-[]-[eating]
#
# Error: [giraffe]-[]-[eating]
#
# Unspecified Error
# 30961
# 8
# (30961, 8): [giraffe]-[]-[eating]
#
# Error: [giraffe]-[]-[eating]
#
# Unspecified Error
# 30961
# 9
# (30961, 9): [giraffe]-[]-[eating]
#
# Error: [giraffe]-[]-[eating]
#
# Unspecified Error
# 30961
# 11
# (30961, 11): [fence]-[]-[wood]
#
# Error: [fence]-[]-[wood]
#
# Unspecified Error
# 30961
# 16
# (30961, 16): [giraffe]-[]-[eating]
#
# Error: [giraffe]-[]-[eating]
#
# Unspecified Error
# 30961
# 17
# (30961, 17): [giraffe]-[]-[eating]
#
# Error: [giraffe]-[]-[eating]
#
# Unspecified Error
# 30961
# 18
# (30961, 18): [giraffe]-[]-[eating]
#
# Error: [giraffe]-[]-[eating]
#
# Unspecified Error
# 30961
# 19
# (30961, 19): [giraffe]-[]-[eating]
#
# Error: [giraffe]-[]-[eating]
#
# Unspecified Error
# 31201
# 18
# (31201, 18): [wall]-[]-[stone]
#
# Error: [wall]-[]-[stone]
#
# Unspecified Error
# 31747
# 17
# (31747, 17): [snow]-[]-[white]
#
# Error: [snow]-[]-[white]
#
# Unspecified Error
# 31747
# 18
# (31747, 18): [snow]-[]-[white]
#
# Error: [snow]-[]-[white]
#
# Unspecified Error
# 31747
# 19
# (31747, 19): [snow]-[]-[white]
#
# Error: [snow]-[]-[white]
#
# Unspecified Error
# 31747
# 20
# (31747, 20): [snow]-[]-[white]
#
# Error: [snow]-[]-[white]
#
# Unspecified Error
# 31747
# 21
# (31747, 21): [snow]-[]-[white]
#
# Error: [snow]-[]-[white]
#
# Unspecified Error
# 31747
# 22
# (31747, 22): [snow]-[]-[white]
#
# Error: [snow]-[]-[white]
#
# Unspecified Error
# 31843
# 17
# (31843, 17): [bottle]-[]-[wine]
#
# Error: [bottle]-[]-[wine]
#
# Unspecified Error
# 31947
# 2
# (31947, 2): [girl]-[]-[barefoot]
#
# Error: [girl]-[]-[barefoot]
#
# Unspecified Error
# 31947
# 3
# (31947, 3): [floor]-[]-[hardwood]
#
# Error: [floor]-[]-[hardwood]
#
# Unspecified Error
# 32712
# 8
# (32712, 8): [man]-[]-[kiteboarding]
#
# Error: [man]-[]-[kiteboarding]
#
# Unspecified Error
# 32712
# 12
# (32712, 12): [man]-[]-[windsurfing]
#
# Error: [man]-[]-[windsurfing]
#
# Unspecified Error
# 32751
# 12
# (32751, 12): [lawn]-[]-[green]
#
# Error: [lawn]-[]-[green]
#
# Unspecified Error
# 32751
# 13
# (32751, 13): [lawn]-[]-[brown]
#
# Error: [lawn]-[]-[brown]
#
# Unspecified Error
# 32751
# 14
# (32751, 14): [collar]-[]-[black]
#
# Error: [collar]-[]-[black]
#
# Unspecified Error
# 32751
# 15
# (32751, 15): [ear]-[]-[upwards]
#
# Error: [ear]-[]-[upwards]
#
# Unspecified Error
# 32751
# 16
# (32751, 16): [ear]-[]-[upwards]
#
# Error: [ear]-[]-[upwards]
#
# Unspecified Error
# 32751
# 17
# (32751, 17): [dog]-[]-[white]
#
# Error: [dog]-[]-[white]
#
# Unspecified Error
# 32751
# 18
# (32751, 18): [ear]-[]-[brown]
#
# Error: [ear]-[]-[brown]
#
# Unspecified Error
# 32751
# 19
# (32751, 19): [ear]-[]-[brown]
#
# Error: [ear]-[]-[brown]
#
# Unspecified Error
# 32751
# 24
# (32751, 24): [book]-[]-[open]
#
# Error: [book]-[]-[open]
#
# Unspecified Error
# 32751
# 30
# (32751, 30): [shrubbery]-[]-[green]
#
# Error: [shrubbery]-[]-[green]
#
# Unspecified Error
# 32751
# 37
# (32751, 37): [collar]-[]-[black]
#
# Error: [collar]-[]-[black]
#
# Unspecified Error
# 32751
# 42
# (32751, 42): [ear]-[]-[brown]
#
# Error: [ear]-[]-[brown]
#
# Unspecified Error
# 32751
# 43
# (32751, 43): [ear]-[]-[brown]
#
# Error: [ear]-[]-[brown]
#
# Unspecified Error
# 32751
# 48
# (32751, 48): [plant]-[]-[leafy]
#
# Error: [plant]-[]-[leafy]
#
# Unspecified Error
# 32751
# 50
# (32751, 50): [collar]-[]-[black]
#
# Error: [collar]-[]-[black]
#
# Unspecified Error
# 32751
# 52
# (32751, 52): [concrete]-[]-[tan]
#
# Error: [concrete]-[]-[tan]
#
# Unspecified Error
# 32751
# 55
# (32751, 55): [leg]-[]-[white]
#
# Error: [leg]-[]-[white]
#
# Unspecified Error
# 32751
# 56
# (32751, 56): [leg]-[]-[white]
#
# Error: [leg]-[]-[white]
#
# Unspecified Error
# 32751
# 58
# (32751, 58): [dog]-[]-[up]
#
# Error: [dog]-[]-[up]
#
# Unspecified Error
# 32751
# 59
# (32751, 59): [plant]-[]-[large]
#
# Error: [plant]-[]-[large]
#
# Unspecified Error
# 32751
# 60
# (32751, 60): [plant]-[]-[green]
#
# Error: [plant]-[]-[green]
#
# Unspecified Error
# 33275
# 26
# (33275, 26): [court]-[]-[grass]
#
# Error: [court]-[]-[grass]
#
# Unspecified Error
# 33729
# 16
# (33729, 16): [cape]-[]-[santa cape]
#
# Error: [cape]-[]-[santa cape]
#
# Unspecified Error
# 33990
# 4
# (33990, 4): [color]-[]-[shape]
#
# Error: [color]-[]-[shape]
#
# 35000 images processed, 738132 relationships
# Unspecified Error
# 37005
# 10
# (37005, 10): [black]-[]-[tire]
#
# Error: [black]-[]-[tire]
#
# Unspecified Error
# 37743
# 16
# (37743, 16): [pole]-[]-[cemented]
#
# Error: [pole]-[]-[cemented]
#
# Unspecified Error
# 38245
# 6
# (38245, 6): [umbrella]-[]-[outside]
#
# Error: [umbrella]-[]-[outside]
#
# Unspecified Error
# 38338
# 7
# (38338, 7): [green]-[]-[sign]
#
# Error: [green]-[]-[sign]
#
# Unspecified Error
# 38570
# 16
# (38570, 16): [word]-[]-[ristorante]
#
# Error: [word]-[]-[ristorante]
#
# 40000 images processed, 836090 relationships
# Unspecified Error
# 40558
# 26
# (40558, 26): [cat]-[]-[sitting]
#
# Error: [cat]-[]-[sitting]
#
# Unspecified Error
# 41371
# 1
# (41371, 1): [crust]-[]-[char]
#
# Error: [crust]-[]-[char]
#
# Unspecified Error
# 41414
# 10
# (41414, 10): [leg]-[]-[raised]
#
# Error: [leg]-[]-[raised]
#
# Unspecified Error
# 41728
# 0
# (41728, 0): [girl]-[]-[sea surfing]
#
# Error: [girl]-[]-[sea surfing]
#
# Unspecified Error
# 41860
# 1
# (41860, 1): [guy]-[]-[bald headed]
#
# Error: [guy]-[]-[bald headed]
#
# 45000 images processed, 944101 relationships
# Unspecified Error
# 47311
# 2
# (47311, 2): [giraffe]-[]-[head]
#
# Error: [giraffe]-[]-[head]
#
# Unspecified Error
# 47311
# 3
# (47311, 3): [giraffe]-[]-[head]
#
# Error: [giraffe]-[]-[head]
#
# Unspecified Error
# 48587
# 6
# (48587, 6): [tie]-[laying]-[on torso]
#
# Error: [tie]-[laying]-[on torso]
#
# 50000 images processed, 1047016 relationships
# Unspecified Error
# 51556
# 23
# (51556, 23): [xbox]-[]-[logo]
#
# Error: [xbox]-[]-[logo]
#
# 55000 images processed, 1147753 relationships
# 60000 images processed, 1256167 relationships
# 65000 images processed, 1372713 relationships
# 70000 images processed, 1478323 relationships
# Unspecified Error
# 71511
# 7
# (71511, 7): [new jersey]-[]-[banner]
#
# Error: [new jersey]-[]-[banner]
#
# 75000 images processed, 1590558 relationships
# Unspecified Error
# 78736
# 12
# (78736, 12): [patch]-[]-[snow]
#
# Error: [patch]-[]-[snow]
#
# Unspecified Error
# 78736
# 13
# (78736, 13): [patch]-[]-[snow]
#
# Error: [patch]-[]-[snow]
#
# Unspecified Error
# 78736
# 14
# (78736, 14): [patch]-[]-[snow]
#
# Error: [patch]-[]-[snow]
#
# Unspecified Error
# 79521
# 18
# (79521, 18): [hat]-[]-[player]
#
# Error: [hat]-[]-[player]
#
# 80000 images processed, 1699863 relationships
# Unspecified Error
# 81192
# 2
# (81192, 2): [bathroom]-[]-[scene]
#
# Error: [bathroom]-[]-[scene]
#
# Unspecified Error
# 81192
# 3
# (81192, 3): [hand]-[]-[persons]
#
# Error: [hand]-[]-[persons]
#
# Unspecified Error
# 81397
# 1
# (81397, 1): [cresting wave]-[]-[breaking]
#
# Error: [cresting wave]-[]-[breaking]
#
# Unspecified Error
# 81494
# 9
# (81494, 9): [guy]-[]-[eating]
#
# Error: [guy]-[]-[eating]
#
# Unspecified Error
# 81499
# 22
# (81499, 22): [is]-[]-[snow]
#
# Error: [is]-[]-[snow]
#
# Unspecified Error
# 81833
# 36
# (81833, 36): [painting]-[]-[farm animals]
#
# Error: [painting]-[]-[farm animals]
#
# Unspecified Error
# 82064
# 46
# (82064, 46): [rain drop]-[]-[falling]
#
# Error: [rain drop]-[]-[falling]
#
# Unspecified Error
# 82064
# 47
# (82064, 47): [rain drop]-[]-[falling]
#
# Error: [rain drop]-[]-[falling]
#
# Unspecified Error
# 82064
# 48
# (82064, 48): [rain drop]-[]-[falling]
#
# Error: [rain drop]-[]-[falling]
#
# Unspecified Error
# 82064
# 49
# (82064, 49): [rain drop]-[]-[falling]
#
# Error: [rain drop]-[]-[falling]
#
# Unspecified Error
# 82064
# 50
# (82064, 50): [rain drop]-[]-[falling]
#
# Error: [rain drop]-[]-[falling]
#
# Unspecified Error
# 82064
# 51
# (82064, 51): [rain drop]-[]-[falling]
#
# Error: [rain drop]-[]-[falling]
#
# Unspecified Error
# 82064
# 52
# (82064, 52): [rain drop]-[]-[falling]
#
# Error: [rain drop]-[]-[falling]
#
# Unspecified Error
# 82064
# 53
# (82064, 53): [rain drop]-[]-[falling]
#
# Error: [rain drop]-[]-[falling]
#
# Unspecified Error
# 82092
# 12
# (82092, 12): [child]-[]-[standing]
#
# Error: [child]-[]-[standing]
#
# Unspecified Error
# 82092
# 13
# (82092, 13): [child]-[]-[skiing]
#
# Error: [child]-[]-[skiing]
#
# Unspecified Error
# 82093
# 22
# (82093, 22): [train]-[]-[moving]
#
# Error: [train]-[]-[moving]
#
# Unspecified Error
# 82125
# 17
# (82125, 17): [this]-[]-[light]
#
# Error: [this]-[]-[light]
#
# Unspecified Error
# 82125
# 27
# (82125, 27): [formation]-[]-[interesting]
#
# Error: [formation]-[]-[interesting]
#
# Unspecified Error
# 82133
# 28
# (82133, 28): [boy]-[]-[surfing]
#
# Error: [boy]-[]-[surfing]
#
# Unspecified Error
# 82133
# 30
# (82133, 30): [wave]-[]-[splashing]
#
# Error: [wave]-[]-[splashing]
#
# Unspecified Error
# 82133
# 31
# (82133, 31): [wave]-[]-[splashing]
#
# Error: [wave]-[]-[splashing]
#
# Unspecified Error
# 82163
# 10
# (82163, 10): [train]-[]-[stop]
#
# Error: [train]-[]-[stop]
#
# Unspecified Error
# 82179
# 28
# (82179, 28): [bear]-[]-[moving]
#
# Error: [bear]-[]-[moving]
#
# Unspecified Error
# 82212
# 2
# (82212, 2): [page]-[]-[mahmood's den]
#
# Error: [page]-[]-[mahmood's den]
#
# Unspecified Error
# 82498
# 3
# (82498, 3): [street]-[]-[cracked]
#
# Error: [street]-[]-[cracked]
#
# Unspecified Error
# 82548
# 20
# (82548, 20): [train]-[]-[parked]
#
# Error: [train]-[]-[parked]
#
# Unspecified Error
# 82624
# 31
# (82624, 31): [zebra]-[]-[eating]
#
# Error: [zebra]-[]-[eating]
#
# Unspecified Error
# 82624
# 32
# (82624, 32): [zebra]-[]-[eating]
#
# Error: [zebra]-[]-[eating]
#
# Unspecified Error
# 82624
# 33
# (82624, 33): [zebra]-[]-[eating]
#
# Error: [zebra]-[]-[eating]
#
# Unspecified Error
# 82624
# 34
# (82624, 34): [zebra]-[]-[eating]
#
# Error: [zebra]-[]-[eating]
#
# Unspecified Error
# 82624
# 35
# (82624, 35): [zebra]-[]-[eating]
#
# Error: [zebra]-[]-[eating]
#
# Unspecified Error
# 82624
# 36
# (82624, 36): [zebra]-[]-[eating]
#
# Error: [zebra]-[]-[eating]
#
# Unspecified Error
# 82624
# 37
# (82624, 37): [zebra]-[]-[eating]
#
# Error: [zebra]-[]-[eating]
#
# Unspecified Error
# 82624
# 38
# (82624, 38): [zebra]-[]-[eating]
#
# Error: [zebra]-[]-[eating]
#
# Unspecified Error
# 82624
# 39
# (82624, 39): [zebra]-[]-[eating]
#
# Error: [zebra]-[]-[eating]
#
# Unspecified Error
# 82624
# 40
# (82624, 40): [giraffe]-[]-[eating]
#
# Error: [giraffe]-[]-[eating]
#
# Unspecified Error
# 82624
# 41
# (82624, 41): [giraffe]-[]-[eating]
#
# Error: [giraffe]-[]-[eating]
#
# Unspecified Error
# 82624
# 42
# (82624, 42): [giraffe]-[]-[eating]
#
# Error: [giraffe]-[]-[eating]
#
# Unspecified Error
# 82624
# 43
# (82624, 43): [giraffe]-[]-[eating]
#
# Error: [giraffe]-[]-[eating]
#
# Unspecified Error
# 82624
# 44
# (82624, 44): [giraffe]-[]-[eating]
#
# Error: [giraffe]-[]-[eating]
#
# Unspecified Error
# 82624
# 45
# (82624, 45): [giraffe]-[]-[eating]
#
# Error: [giraffe]-[]-[eating]
#
# Unspecified Error
# 82624
# 46
# (82624, 46): [giraffe]-[]-[eating]
#
# Error: [giraffe]-[]-[eating]
#
# Unspecified Error
# 82624
# 47
# (82624, 47): [giraffe]-[]-[eating]
#
# Error: [giraffe]-[]-[eating]
#
# Unspecified Error
# 82624
# 48
# (82624, 48): [giraffe]-[]-[eating]
#
# Error: [giraffe]-[]-[eating]
#
# Unspecified Error
# 82624
# 49
# (82624, 49): [giraffe]-[]-[eating]
#
# Error: [giraffe]-[]-[eating]
#
# Unspecified Error
# 82858
# 34
# (82858, 34): [car]-[]-[parked]
#
# Error: [car]-[]-[parked]
#
# Unspecified Error
# 83024
# 23
# (83024, 23): [sheep]-[]-[white]
#
# Error: [sheep]-[]-[white]
#
# Unspecified Error
# 83218
# 12
# (83218, 12): [this]-[]-[elephant]
#
# Error: [this]-[]-[elephant]
#
# Unspecified Error
# 83371
# 32
# (83371, 32): [tail]-[]-[bird]
#
# Error: [tail]-[]-[bird]
#
# Unspecified Error
# 83436
# 38
# (83436, 38): [girl]-[]-[playing]
#
# Error: [girl]-[]-[playing]
#
# Unspecified Error
# 83488
# 20
# (83488, 20): [young man]-[]-[skateboarding]
#
# Error: [young man]-[]-[skateboarding]
#
# Unspecified Error
# 83561
# 69
# (83561, 69): [airplane]-[]-[parked]
#
# Error: [airplane]-[]-[parked]
#
# Unspecified Error
# 83561
# 70
# (83561, 70): [airplane]-[]-[parked]
#
# Error: [airplane]-[]-[parked]
#
# Unspecified Error
# 83561
# 71
# (83561, 71): [airplane]-[]-[parked]
#
# Error: [airplane]-[]-[parked]
#
# Unspecified Error
# 83633
# 7
# (83633, 7): [this]-[]-[airplane]
#
# Error: [this]-[]-[airplane]
#
# Unspecified Error
# 83670
# 43
# (83670, 43): [paw]-[]-[wet]
#
# Error: [paw]-[]-[wet]
#
# Unspecified Error
# 84110
# 1
# (84110, 1): [man]-[]-[skiing]
#
# Error: [man]-[]-[skiing]
#
# Unspecified Error
# 84110
# 5
# (84110, 5): [lady]-[]-[skiing]
#
# Error: [lady]-[]-[skiing]
#
# Unspecified Error
# 84127
# 15
# (84127, 15): [elephant]-[]-[walking]
#
# Error: [elephant]-[]-[walking]
#
# Unspecified Error
# 84258
# 24
# (84258, 24): [man]-[]-[skiing]
#
# Error: [man]-[]-[skiing]
#
# Unspecified Error
# 84259
# 27
# (84259, 27): [plane]-[]-[remote control]
#
# Error: [plane]-[]-[remote control]
#
# Unspecified Error
# 84588
# 23
# (84588, 23): [this]-[]-[kitchen]
#
# Error: [this]-[]-[kitchen]
#
# 85000 images processed, 1792497 relationships
# Unspecified Error
# 85456
# 17
# (85456, 17): [snow]-[]-[white]
#
# Error: [snow]-[]-[white]
#
# Unspecified Error
# 85946
# 1
# (85946, 1): [this]-[]-[scene]
#
# Error: [this]-[]-[scene]
#
# Unspecified Error
# 85946
# 2
# (85946, 2): [this]-[]-[scene]
#
# Error: [this]-[]-[scene]
#
# Unspecified Error
# 86514
# 6
# (86514, 6): [bear]-[]-[walking]
#
# Error: [bear]-[]-[walking]
#
# Unspecified Error
# 86514
# 7
# (86514, 7): [bear]-[]-[walking]
#
# Error: [bear]-[]-[walking]
#
# Unspecified Error
# 87022
# 2
# (87022, 2): [this]-[]-[scene]
#
# Error: [this]-[]-[scene]
#
# Unspecified Error
# 87152
# 8
# (87152, 8): [roof]-[]-[doomed]
#
# Error: [roof]-[]-[doomed]
#
# Unspecified Error
# 88073
# 2
# (88073, 2): [sky]-[]-[cloudy]
#
# Error: [sky]-[]-[cloudy]
#
# Unspecified Error
# 88378
# 2
# (88378, 2): [scene]-[]-[inside]
#
# Error: [scene]-[]-[inside]
#
# Unspecified Error
# 88967
# 19
# (88967, 19): [elephant]-[]-[walking]
#
# Error: [elephant]-[]-[walking]
#
# Unspecified Error
# 89171
# 26
# (89171, 26): [decal]-[]-[froster]
#
# Error: [decal]-[]-[froster]
#
# Unspecified Error
# 89488
# 2
# (89488, 2): [sidewalk]-[]-[bricks]
#
# Error: [sidewalk]-[]-[bricks]
#
# Unspecified Error
# 89490
# 0
# (89490, 0): [scene]-[]-[outside]
#
# Error: [scene]-[]-[outside]
#
# Unspecified Error
# 89532
# 12
# (89532, 12): [grape]-[]-[purple]
#
# Error: [grape]-[]-[purple]
#
# Unspecified Error
# 89532
# 15
# (89532, 15): [basket]-[]-[white]
#
# Error: [basket]-[]-[white]
#
# Unspecified Error
# 89532
# 18
# (89532, 18): [muffin]-[]-[brown]
#
# Error: [muffin]-[]-[brown]
#
# Unspecified Error
# 89533
# 5
# (89533, 5): [this]-[]-[syrup]
#
# Error: [this]-[]-[syrup]
#
# 90000 images processed, 1864085 relationships
# 95000 images processed, 1957889 relationships
# 100000 images processed, 2063399 relationships
# Unspecified Error
# 100100
# 39
# (100100, 39): [suitcase]-[]-[bottle]
#
# Error: [suitcase]-[]-[bottle]
#
# Unspecified Error
# 102193
# 58
# (102193, 58): [cat]-[]-[head]
#
# Error: [cat]-[]-[head]
#
# Unspecified Error
# 102529
# 35
# (102529, 35): [traffic light]-[]-[yellow]
#
# Error: [traffic light]-[]-[yellow]
#
# Unspecified Error
# 102529
# 36
# (102529, 36): [traffic]-[]-[yellow]
#
# Error: [traffic]-[]-[yellow]
#
# Unspecified Error
# 102529
# 40
# (102529, 40): [cone]-[]-[orange]
#
# Error: [cone]-[]-[orange]
#
# Unspecified Error
# 102529
# 41
# (102529, 41): [arrow]-[]-[white]
#
# Error: [arrow]-[]-[white]
#
# Unspecified Error
# 102529
# 50
# (102529, 50): [traffic light]-[]-[yellow]
#
# Error: [traffic light]-[]-[yellow]
#
# Unspecified Error
# 103003
# 0
# (103003, 0): [airplane]-[]-[flying]
#
# Error: [airplane]-[]-[flying]
#
# 105000 images processed, 2184203 relationships
# Unspecified Error
# 106714
# 5
# (106714, 5): [nail]-[]-[man]
#
# Error: [nail]-[]-[man]
#
# Currently, we have 2240448 relationship tuples and 104690 images
# Spelling error: 68997
# Length matching error: 6460

# %% [markdown]
# # Filtering the Top-50 predicate and Top-150 object categories

# %%
def get_object_predicate_list(relationships):
    object_list = set()
    predicate_list = set()
    for im_id in relationships:
        for r_id, relationship_item in enumerate(relationships[im_id]['relationships']):
            object_list.add(relationship_item['subject'])
            object_list.add(relationship_item['object'])
            predicate_list.add(relationship_item['predicate'])
            
    print "Object classes: %d\nPredicate classes: %d\n" % (len(object_list), len(predicate_list))
    return object_list, predicate_list
    
def object_predicate_categories_count(relationships):
    object_list, predicate_list = get_object_predicate_list(relationships)
    freq_obj = {x:0 for x in object_list}
    freq_pred = {x:0 for x in predicate_list}
    for im_id in relationships:
        for r_id, relationship_item in enumerate(relationships[im_id]['relationships']):
            temp_sub = relationship_item['subject']
            temp_obj = relationship_item['object']
            temp_predicate = relationship_item['predicate']
            freq_obj[temp_sub] += 1    
            freq_obj[temp_obj] += 1
            freq_pred[temp_predicate] += 1    
    return freq_obj, freq_pred

def filter_categories(original_relationships, top_n_obj=150, top_n_pred=50):
    import copy
    original_im_num = len(original_relationships.keys())
    relationships = copy.deepcopy(original_relationships)
    freq_obj, freq_pred = object_predicate_categories_count(relationships)
    import operator
    sorted_obj = sorted(freq_obj.items(), key=operator.itemgetter(1), reverse=True)
    sorted_pred = sorted(freq_pred.items(), key=operator.itemgetter(1), reverse=True)
    selected_obj = set(x[0] for x in sorted_obj[:top_n_obj])
    selected_pred = set(x[0] for x in sorted_pred[:top_n_pred])
    for im_id in relationships.keys():
        for relationship_item in list(relationships[im_id]['relationships']):
            temp_sub = relationship_item['subject']
            temp_obj = relationship_item['object']
            temp_predicate = relationship_item['predicate']
            if temp_sub not in selected_obj or temp_obj not in selected_obj or temp_predicate not in selected_pred:
                relationships[im_id]['relationships'].remove(relationship_item)
        if len(relationships[im_id]['relationships']) == 0:
            relationships.pop(im_id)
    print "%d images left(%d/%d removed)" % \
        (len(relationships.keys()), original_im_num - len(relationships.keys()), original_im_num)
         
    return relationships, selected_obj, selected_pred

def count_instance_num(relationships):
    instance_counter = 0
    for im_id in relationships.keys():
        instance_counter+= len(relationships[im_id]['relationships'])  
    return instance_counter

def im_with_N_more_instances(relationships, N = 15):
    id_list = []
    for im_id in relationships.keys():
        if len(relationships[im_id]['relationships']) >= N:
            id_list.append(im_id)
    print "%d images with more than %d instances" % (len(id_list), N)
    return id_list

def select_top_N_ims(relationships, N):
    import operator
    instance_num = [(x, len(relationships[x]['relationships'])) for x in relationships]
    id_list = sorted(instance_num, key=operator.itemgetter(1), reverse=True)
    assert N<=len(id_list), "Select %d images from %d" % (N, len(id_list))
    return [x[0] for x in id_list[:N]]

# %% [markdown]
# ## Now filter out the long-tail categories

# %%
relationships, selected_obj, selected_pred = filter_categories(imported_data.relationships)
freq_obj, freq_pred = object_predicate_categories_count(relationships)
# Out:
# Object classes: 48597
# Predicate classes: 28987
#
# 95999 images left(8691/104690 removed)
# Object classes: 150
# Predicate classes: 50

# %%
def count_training_weight(relationships):
    import numpy as np
    freq_obj, freq_pred = object_predicate_categories_count(relationships)
    total_counter_obj = 0
    total_counter_pred = 0
    inverse_weight_pred = {}
    inverse_weight_obj = {}
    print '========= counting result ========'
    print '------------ object --------------'
    for c in freq_obj:
        print '[{}]: {}'.format(c, freq_obj[c])
        total_counter_obj += freq_obj[c]
    print '----------- predicate ------------'
    for c in freq_pred:
        print '[{}]: {}'.format(c, freq_pred[c])
        total_counter_pred+= freq_pred[c]
    print '========= counting result ========'
    print '------------ object --------------'
    for c in freq_obj:
        print '[{}]: {}'.format(c, np.sqrt(total_counter_obj / freq_obj[c] / 150.))
        inverse_weight_obj[c] = np.sqrt(total_counter_obj / freq_obj[c] / 150.)
    print '----------- predicate ------------'
    for c in freq_pred:
        print '[{}]: {}'.format(c, np.sqrt(total_counter_pred / freq_pred[c]  / 50.))
        inverse_weight_pred[c] = np.sqrt(total_counter_pred / freq_pred[c] / 50.)
    
    return inverse_weight_obj, inverse_weight_pred
    
def output_inverse_weight(filename, inverse_weight_obj, inverse_weight_pred):
    import json
    inverse_weight = {'object': inverse_weight_obj, 'predicate': inverse_weight_pred}
    with open(filename, 'w') as fp:
        json.dump(inverse_weight, fp)

# %% [markdown]
# ## Partition dataset
#
# 1. subsample 25000 images for testing;
# 2. remaining 70999 images for training;
# 3. Different training/testing settings
#     - original dataset: 70999 images for training and 25000 images for testing
#     - Small dataset: 15000 images for training and 5000 for testing
#     - Fat Dataset： 15000 images with 15+ instances for training and 5000 for testing

# %%
import random
im_list_full = relationships.keys()
random.shuffle(im_list_full)
training_list = im_list_full[:-25000]
testing_list = im_list_full[-25000:]
training_set = {x:relationships[x] for x in training_list}
testing_set = {x:relationships[x] for x in testing_list}
training_small_list = training_list[:15000]
testing_small_list = testing_list[:5000]
training_fat_list = select_top_N_ims(training_set, 15000)

# %% [markdown]
# ## Loading region description dataset

# %%
import json
region_data = json.load(open('../region_descriptions_v2.json'))

# %%
def object_matching(objects, rel):
    obj_item = {}
    obj_item['class'] = rel['object']
    obj_item['box'] = rel['obj_box']
    sub_item = {}
    sub_item['class'] = rel['subject']
    sub_item['box'] = rel['sub_box']
    
    obj_id = -1
    sub_id = -1
    
    for idx, obj in enumerate(objects):
        if obj_item == obj:
            obj_id = idx
        if sub_item == obj:
            sub_id = idx
    if sub_id < 0 or obj_id < 0:
        raise Exception('Object Matching Error!')
        
    return sub_id, obj_id

def check_is_included(objects, obj_item):
    for ex_obj in objects:
        if ex_obj == obj_item:
            return True
    return False

def dataset_setup(id_list, relationships, raw_region_data):
    import copy
    import string
    replace_punctuation = string.maketrans(string.punctuation, ' '*len(string.punctuation))
    dataset = []
    ignore_counter_out = 0
    ignore_counter_small = 0
    ignore_counter_short = 0
    ignore_counter_object_small = 0
    region_counter = 0
    region_min_num = 1000
    rel_counter = 0
    for im_id in id_list:
        im_item = {}
        im_item['id'] = im_id
        im_item['path'] = relationships[im_id]['path']
        im_item['height'] = relationships[im_id]['height']
        im_item['width'] = relationships[im_id]['width']
        regions = []
        objects = []
        relationships_new = []
        for region in raw_region_data[im_id]['regions']:
            region_item = {}
            # print region['phrase']
            region_item['phrase'] = region['phrase'].encode('ascii', 'ignore').lower().translate(replace_punctuation)
            # index starts from 
            region_item['box'] = (region['x'] , region['y'] , \
                                  region['x'] + region['width'] - 1, \
                                  region['y'] + region['height'] - 1)
            if region_item['box'][0] < 0 or region_item['box'][1] < 0 or region_item['box'][2] >= im_item['width'] or region_item['box'][3] >= im_item['height']:
#                 print 'ignore regions: (%d %d %d %d) in image(%d %d)' % \
#                         (region_item['box'][0], region_item['box'][1], region_item['box'][2], region_item['box'][3], im_item['width'], im_item['height'])
                ignore_counter_out += 1
            elif region_item['box'][3] - region_item['box'][1] < 64 or region_item['box'][2] - region_item['box'][0] < 64:
                ignore_counter_small += 1
#                 print 'Region too small: (%d %d %d %d)' % \
#                     (region_item['box'][0], region_item['box'][1], region_item['box'][2], region_item['box'][3])
            elif len(region_item['phrase'].split()) < 3:
                ignore_counter_short += 1
            else:
                region_counter+=1
                regions.append(region_item)
        if len(regions) < region_min_num:
            region_min_num = len(regions)
        for rel in relationships[im_id]['relationships']:
            obj_item = {}
            obj_item['class'] = rel['object']
            obj_item['box'] = rel['obj_box']
            if obj_item['box'][0] < 0 or obj_item['box'][1] < 0 or obj_item['box'][2] >= im_item['width'] or obj_item['box'][3] >= im_item['height']:
#                 print 'ignore relationship: (%d %d %d %d) in image(%d %d)' % \
#                         (obj_item['box'][0], obj_item['box'][1], obj_item['box'][2], obj_item['box'][3], im_item['width'], im_item['height'])
                continue
            elif obj_item['box'][3] - obj_item['box'][1] < 32 or obj_item['box'][2] - obj_item['box'][0] < 32:
                ignore_counter_object_small += 1
                continue 
#             obj_item['box'][2] = min(obj_item['box'][2], im_item['width'] - 1)
#             obj_item['box'][3] = min(obj_item['box'][3], im_item['height'] - 1)
            sub_item = {}
            sub_item['class'] = rel['subject']
            sub_item['box'] = rel['sub_box']
            if sub_item['box'][0] < 0 or sub_item['box'][1] < 0 or sub_item['box'][2] >= im_item['width'] or sub_item['box'][3] >= im_item['height']:
#                 print 'ignore relationship: (%d %d %d %d) in image(%d %d)'% \
#                         (sub_item['box'][0], sub_item['box'][1], sub_item['box'][2], sub_item['box'][3], im_item['width'], im_item['height'])
                continue
            elif sub_item['box'][3] - sub_item['box'][1] < 16 or sub_item['box'][2] - sub_item['box'][0] < 16:
                ignore_counter_object_small += 1
                continue 
            
#             sub_item['box'][2] = min(sub_item['box'][2], im_item['width'] - 1)
#             sub_item['box'][3] = min(sub_item['box'][3], im_item['height'] - 1)
            rel_item = {}
            if not check_is_included(objects, obj_item):
                objects.append(obj_item)
            if not check_is_included(objects, sub_item):
                objects.append(sub_item)    
            rel_item['sub_id'], rel_item['obj_id'] = object_matching(objects, rel)
            rel_item['predicate'] = rel['predicate']
            rel_counter+=1
            relationships_new.append(rel_item)
        if len(relationships_new) > 0 and len(regions) > 0:
            im_item['regions'] = regions
            im_item['objects'] = objects
            im_item['relationships'] = relationships_new
            dataset.append(im_item)
        
    print 'Ignore %d (small) and %d (out) and %d (short) regions... Remaining: %d regions (%.2f/im, min: %d)' % \
        (ignore_counter_small, ignore_counter_out, ignore_counter_short, region_counter, region_counter / len(id_list), region_min_num)
    print 'Ignore %d (small) relationships... Remaining: %d relationships (%.2f/im)' % \
        (ignore_counter_object_small, rel_counter, rel_counter / len(id_list))
    print 'Total: %d images (%d filtered)' % (len(dataset), len(id_list) - len(dataset))
    return dataset

def output_dataset(dataset, filename):
    import json
    with open(filename, 'w') as fp:
        json.dump(dataset, fp)
    print "Done output dataset: "+filename
    
def output_category_list(selected_obj, selected_pred, filename):
    categories = {'object': list(selected_obj), 'predicate': list(selected_pred)}
    
    import json
    with open(filename, 'w') as fp:
        json.dump(categories, fp)
    print "Done output category list: " + filename

# %%
training_small_set = dataset_setup(training_small_list, relationships, region_data)
testing_small_set = dataset_setup(testing_small_list, relationships, region_data)
training_set = dataset_setup(training_list, relationships, region_data)
testing_set = dataset_setup(testing_list, relationships, region_data)
training_fat_set = dataset_setup(training_fat_list, relationships, region_data)
# Out:
# Ignore 396496 (small) and 749 (out) and 4938 (short) regions... Remaining: 350336 regions (23.00/im, min: 0)
# Ignore 36935 (small) relationships... Remaining: 101855 relationships (6.00/im)
# Total: 14458 images (542 filtered)
# Ignore 132273 (small) and 285 (out) and 1627 (short) regions... Remaining: 116290 regions (23.00/im, min: 1)
# Ignore 12199 (small) relationships... Remaining: 33737 relationships (6.00/im)
# Total: 4826 images (174 filtered)
# Ignore 1876611 (small) and 3562 (out) and 22831 (short) regions... Remaining: 1648558 regions (23.00/im, min: 0)
# Ignore 174199 (small) relationships... Remaining: 479861 relationships (6.00/im)
# Total: 68446 images (2553 filtered)
# Ignore 659387 (small) and 1222 (out) and 8138 (short) regions... Remaining: 581629 regions (23.00/im, min: 0)
# Ignore 61631 (small) relationships... Remaining: 168375 relationships (6.00/im)
# Total: 24126 images (874 filtered)
# Ignore 415995 (small) and 647 (out) and 4339 (short) regions... Remaining: 335874 regions (22.00/im, min: 0)
# Ignore 88988 (small) relationships... Remaining: 221324 relationships (14.00/im)
# Total: 14931 images (69 filtered)

# %%
output_dir = 'output/top_150_50_big/'
output_dataset(training_set, output_dir+'train.json')
output_dataset(testing_set, output_dir+'test.json')
output_dataset(training_small_set, output_dir+'train_small.json')
output_dataset(testing_small_set, output_dir+'test_small.json')
output_dataset(training_fat_set, output_dir+'train_fat.json')
output_category_list(selected_obj, selected_pred, output_dir + 'categories.json')
inverse_weight_obj, inverse_weight_pred = count_training_weight(relationships)
output_inverse_weight(output_dir + 'inverse_weight.json', inverse_weight_obj, inverse_weight_pred)
# Out:
# Done output dataset: output/top_150_50_big/train.json
# Done output dataset: output/top_150_50_big/test.json
# Done output dataset: output/top_150_50_big/train_small.json
# Done output dataset: output/top_150_50_big/test_small.json
# Done output dataset: output/top_150_50_big/train_fat.json
# Done output category list: output/top_150_50_big/categories.json
# Object classes: 150
# Predicate classes: 50
#
# ========= counting result ========
# ------------ object --------------
# [bush]: 4869
# [kite]: 5735
# [pant]: 11073
# [laptop]: 4005
# [paper]: 3494
# [shoe]: 10701
# [chair]: 8975
# [ground]: 24742
# [tire]: 5553
# [cup]: 3511
# [sky]: 33961
# [bench]: 9558
# [tail]: 11370
# [bike]: 7198
# [board]: 3931
# [hat]: 13916
# [skier]: 3803
# [plate]: 15009
# [woman]: 46337
# [handle]: 4007
# [food]: 6413
# [bear]: 10177
# [wave]: 5988
# [giraffe]: 20126
# [background]: 7082
# [desk]: 3735
# [foot]: 7594
# [shadow]: 13425
# [lady]: 3088
# [button]: 2240
# [glove]: 4576
# [bag]: 5955
# [sand]: 5744
# [nose]: 10954
# [rock]: 8633
# [sidewalk]: 10652
# [motorcycle]: 8378
# [fence]: 9813
# [people]: 10349
# [house]: 5786
# [sign]: 22763
# [hair]: 16121
# [street]: 13893
# [bed]: 7515
# [mirror]: 6947
# [logo]: 4586
# [girl]: 13324
# [arm]: 7311
# [flower]: 9691
# [leaf]: 17502
# [clock]: 12864
# [dirt]: 4689
# [hill]: 4502
# [bird]: 11103
# [umbrella]: 7713
# [leg]: 22375
# [reflection]: 4983
# [water]: 25425
# [sink]: 2592
# [trunk]: 5189
# [post]: 4224
# [tower]: 4800
# [box]: 3784
# [boy]: 17339
# [cow]: 10342
# [skateboard]: 9972
# [pillow]: 6053
# [road]: 15111
# [wall]: 25680
# [number]: 6511
# [pole]: 16600
# [table]: 25602
# [boat]: 10872
# [sheep]: 8176
# [horse]: 13977
# [eye]: 15735
# [top]: 3677
# [window]: 58491
# [vehicle]: 3487
# [brick]: 3930
# [banana]: 3899
# [ceiling]: 3750
# [door]: 9745
# [shelf]: 5467
# [glass]: 14354
# [cloud]: 24996
# [train]: 25444
# [child]: 5281
# [line]: 8527
# [ear]: 16672
# [neck]: 3670
# [ski]: 4682
# [cap]: 4891
# [tree]: 40145
# [roof]: 4329
# [cat]: 15227
# [cake]: 3056
# [grass]: 23200
# [zebra]: 16663
# [toilet]: 2955
# [head]: 24350
# [bus]: 18074
# [player]: 5719
# [airplane]: 6314
# [face]: 7887
# [car]: 17808
# [helmet]: 7921
# [shirt]: 35431
# [floor]: 7958
# [headlight]: 5134
# [bowl]: 3722
# [snow]: 15453
# [couch]: 3733
# [field]: 15233
# [lamp]: 3215
# [book]: 4596
# [branch]: 5171
# [elephant]: 16553
# [tile]: 6282
# [beach]: 9998
# [pizza]: 4865
# [wheel]: 13011
# [picture]: 6111
# [plant]: 4540
# [sandwich]: 2103
# [mountain]: 4887
# [track]: 10251
# [spot]: 6437
# [hand]: 18042
# [plane]: 15519
# [mouth]: 4900
# [stripe]: 7536
# [letter]: 7415
# [vase]: 6498
# [man]: 115889
# [building]: 52598
# [short]: 8789
# [surfboard]: 7982
# [phone]: 4395
# [light]: 17989
# [counter]: 3434
# [dog]: 14590
# [ocean]: 4791
# [jacket]: 10465
# [person]: 51188
# [part]: 4419
# [truck]: 7767
# [bottle]: 5604
# [jean]: 5648
# [wing]: 5089
# ----------- predicate ------------
# [wearing]: 62730
# [in_a]: 2597
# [be_on]: 4360
# [over]: 2693
# [at]: 3015
# [have]: 120037
# [in]: 92930
# [carry]: 2492
# [rid]: 5560
# [have_a]: 11111
# [inside_of]: 743
# [wear_a]: 5127
# [for]: 1336
# [in_front_of]: 6644
# [hang_on]: 2193
# [on_top_of]: 10747
# [below]: 1642
# [by]: 7756
# [beside]: 3549
# [behind]: 22205
# [above]: 6122
# [under]: 7311
# [on_front_of]: 1987
# [lay_on]: 1776
# [around]: 1737
# [on_a]: 13079
# [sit_on]: 7644
# [between]: 1080
# [watch]: 1213
# [belong_to]: 2262
# [wear]: 9244
# [walk_on]: 3319
# [along]: 1381
# [hold]: 13591
# [with]: 22253
# [eat]: 3073
# [stand_on]: 4929
# [on]: 291077
# [next_to]: 11197
# [on_side_of]: 5951
# [attach_to]: 3260
# [of]: 64200
# [inside]: 1435
# [cover]: 2674
# [hang_from]: 1382
# [near]: 13831
# [stand_in]: 3620
# [sit_in]: 1688
# [be_in]: 2409
# [of_a]: 9890
# ========= counting result ========
# ------------ object --------------
# [bush]: 1.55563491861
# [kite]: 1.43294568401
# [pant]: 1.0295630141
# [laptop]: 1.71464281995
# [paper]: 1.83666364186
# [shoe]: 1.04880884817
# [chair]: 1.14600756251
# [ground]: 0.687992248018
# [tire]: 1.45602197786
# [cup]: 1.83121089264
# [sky]: 0.588784057755
# [bench]: 1.10754984839
# [tail]: 1.01653004547
# [bike]: 1.27801930085
# [board]: 1.73012523631
# [hat]: 0.920144916123
# [skier]: 1.7587874611
# [plate]: 0.883176086633
# [woman]: 0.503322295685
# [handle]: 1.71464281995
# [food]: 1.35400640077
# [bear]: 1.07393357957
# [wave]: 1.4023789312
# [giraffe]: 0.761577310586
# [background]: 1.28840987267
# [desk]: 1.77576274692
# [foot]: 1.24365054041
# [shadow]: 0.934523051258
# [lady]: 1.95277580212
# [button]: 2.29346898824
# [glove]: 1.6041612554
# [bag]: 1.40475383371
# [sand]: 1.43061758226
# [nose]: 1.03601801786
# [rock]: 1.16619037897
# [sidewalk]: 1.04880884817
# [motorcycle]: 1.18602979164
# [fence]: 1.09544511501
# [people]: 1.06458129484
# [house]: 1.42594997575
# [sign]: 0.716472842007
# [hair]: 0.852447456836
# [street]: 0.920144916123
# [bed]: 1.25166555703
# [mirror]: 1.30128141973
# [logo]: 1.60208197876
# [girl]: 0.938083151965
# [arm]: 1.26754355612
# [flower]: 1.10151410946
# [leaf]: 0.820568908339
# [clock]: 0.955684745789
# [dirt]: 1.58534959341
# [hill]: 1.61658075373
# [bird]: 1.0295630141
# [umbrella]: 1.23558353286
# [leg]: 0.725718035236
# [reflection]: 1.53622914957
# [water]: 0.678232998313
# [sink]: 2.13229141223
# [trunk]: 1.50554530542
# [post]: 1.66933120341
# [tower]: 1.5663120166
# [box]: 1.76446403572
# [boy]: 0.820568908339
# [cow]: 1.06458129484
# [skateboard]: 1.08627804912
# [pillow]: 1.3952299691
# [road]: 0.883176086633
# [wall]: 0.673300329224
# [number]: 1.34412301024
# [pole]: 0.840634680861
# [table]: 0.678232998313
# [boat]: 1.03923048454
# [sheep]: 1.2
# [horse]: 0.916515138991
# [eye]: 0.864098759788
# [top]: 1.788854382
# [window]: 0.4472135955
# [vehicle]: 1.83847763109
# [brick]: 1.73012523631
# [banana]: 1.7378147197
# [ceiling]: 1.77200451467
# [door]: 1.09848380355
# [shelf]: 1.46742404687
# [glass]: 0.905538513814
# [cloud]: 0.683130051064
# [train]: 0.678232998313
# [child]: 1.49220195237
# [line]: 1.17473401245
# [ear]: 0.840634680861
# [neck]: 1.79071680248
# [ski]: 1.58534959341
# [cap]: 1.55134350376
# [tree]: 0.541602560309
# [roof]: 1.64924225025
# [cat]: 0.879393730552
# [cake]: 1.96299091524
# [grass]: 0.711805216802
# [zebra]: 0.840634680861
# [toilet]: 1.99666388425
# [head]: 0.692820323028
# [bus]: 0.804155872121
# [player]: 1.43527000944
# [airplane]: 1.36626010213
# [face]: 1.22202018532
# [car]: 0.812403840464
# [helmet]: 1.21928941054
# [shirt]: 0.571547606649
# [floor]: 1.21655250606
# [headlight]: 1.51437555888
# [bowl]: 1.77951304201
# [snow]: 0.871779788708
# [couch]: 1.77576274692
# [field]: 0.879393730552
# [lamp]: 1.91311264697
# [book]: 1.6
# [branch]: 1.50775771705
# [elephant]: 0.840634680861
# [tile]: 1.36869767784
# [beach]: 1.08320512062
# [pizza]: 1.55563491861
# [wheel]: 0.948683298051
# [picture]: 1.38804418758
# [plant]: 1.61038297722
# [sandwich]: 2.36643191324
# [mountain]: 1.55134350376
# [track]: 1.07082522695
# [spot]: 1.35154232885
# [hand]: 0.808290376865
# [plane]: 0.867947771086
# [mouth]: 1.54919333848
# [stripe]: 1.24899959968
# [letter]: 1.25962957518
# [vase]: 1.34660065845
# [man]: 0.316227766017
# [building]: 0.469041575982
# [short]: 1.15758369028
# [surfboard]: 1.2138094304
# [phone]: 1.63707055437
# [light]: 0.808290376865
# [counter]: 1.85112578359
# [dog]: 0.89814623902
# [ocean]: 1.56843871414
# [jacket]: 1.05830052443
# [person]: 0.47609522857
# [part]: 1.63299316186
# [truck]: 1.23017613915
# [bottle]: 1.44913767462
# [jean]: 1.444529912
# [wing]: 1.52096460621
# ----------- predicate ------------
# [wearing]: 0.529150262213
# [in_a]: 2.60768096208
# [be_on]: 2.00997512422
# [over]: 2.56124969497
# [at]: 2.42074368738
# [have]: 0.374165738677
# [in]: 0.424264068712
# [carry]: 2.66082693913
# [rid]: 1.78325545001
# [have_a]: 1.256980509
# [inside_of]: 4.87647413609
# [wear_a]: 1.8547236991
# [for]: 3.63593179254
# [in_front_of]: 1.63095064303
# [hang_on]: 2.83901391332
# [on_top_of]: 1.28062484749
# [below]: 3.28024389337
# [by]: 1.50332963784
# [beside]: 2.23159136044
# [behind]: 0.883176086633
# [above]: 1.69705627485
# [under]: 1.54919333848
# [on_front_of]: 2.97993288515
# [lay_on]: 3.15277655409
# [around]: 3.1874754901
# [on_a]: 1.15758369028
# [sit_on]: 1.51657508881
# [between]: 4.04474968323
# [watch]: 3.81575680567
# [belong_to]: 2.79284800875
# [wear]: 1.37840487521
# [walk_on]: 2.30651251893
# [along]: 3.577708764
# [hold]: 1.1401754251
# [with]: 0.883176086633
# [eat]: 2.39582971014
# [stand_on]: 1.89208879284
# [on]: 0.244948974278
# [next_to]: 1.24899959968
# [on_side_of]: 1.72046505341
# [attach_to]: 2.32808934536
# [of]: 0.509901951359
# [inside]: 3.50998575496
# [cover]: 2.56904651573
# [hang_from]: 3.57491258634
# [near]: 1.12249721603
# [stand_in]: 2.20907220344
# [sit_in]: 3.23419232576
# [be_in]: 2.70554985169
# [of_a]: 1.33416640641

# %% [markdown]
# ## Buildup dictionary for sentences

# %%
class Dictionary(object):
    def __init__(self):
        self.word2idx = {}
        self.idx2word = []

    def add_word(self, word):
        if word not in self.word2idx:
            self.idx2word.append(word)
            self.word2idx[word] = len(self.idx2word) - 1
        return self.word2idx[word]

    def __len__(self):
        return len(self.idx2word)

def buildup_dictionary(trainset, testset, filename):
    import json
    dictionary = Dictionary()
    print('First, training set...')
    for im in trainset:
        for region in im['regions']:
            words = region['phrase'].split() + ['<eos>']
            for word in words:
                    dictionary.add_word(word)
    print('Then, testing set...')
    for im in testset:
        for region in im['regions']:
            words = region['phrase'].split() + ['<eos>']
            for word in words:
                    dictionary.add_word(word)
                    
    print 'Dictionary has %d words' % len(dictionary.idx2word)
    dict_ = {'word2idx': dictionary.word2idx, 'idx2word': dictionary.idx2word}
    with open(filename, 'w') as fp:
        json.dump(dict_, fp)
    print "Done output category list: " + filename
    return dict_

# %%
buildup_dictionary(training_set, testing_set, output_dir+'dict.json')
# Out:
# First, training set...
# Then, testing set...
# Dictionary has 39393 words
# Done output category list: output/top_150_50_big/dict.json
# {'idx2word': ['the',
#   'man',
#   'is',
#   'laughing',
#   '<eos>',
#   'people',
#   'are',
#   'riding',
#   'on',
#   'bicycles',
#   'buildings',
#   'in',
#   'background',
#   'tall',
#   'has',
#   'a',
#   'brown',
#   'jacket',
#   'black',
#   'and',
#   'tan',
#   'backpack',
#   'person',
#   'bicycle',
#   'wearing',
#   'sunglasses',
#   'hat',
#   'helmet',
#   'woman',
#   'bag',
#   'red',
#   'maroon',
#   'orange',
#   'pant',
#   'sits',
#   'bike',
#   'blue',
#   'rides',
#   'holds',
#   'drink',
#   'his',
#   'hand',
#   'sky',
#   'scraper',
#   'hats',
#   'bench',
#   'colorful',
#   'dark',
#   'photo',
#   'light',
#   'ground',
#   'rim',
#   'of',
#   'green',
#   'pruple',
#   'next',
#   'to',
#   'one',
#   'top',
#   'rainbow',
#   'under',
#   'ranbow',
#   'colored',
#   'two',
#   'six',
#   'many',
#   'color',
#   'kept',
#   'sitting',
#   'made',
#   'with',
#   'steel',
#   'near',
#   'coated',
#   'arranged',
#   'same',
#   'row',
#   'table',
#   'corner',
#   'there',
#   '6',
#   'puffy',
#   'clouds',
#   'white',
#   'plane',
#   'tail',
#   'grey',
#   'engine',
#   'silver',
#   'lights',
#   'pole',
#   'wheels',
#   'airplane',
#   'stripe',
#   'mountain',
#   'range',
#   'patches',
#   'vegetation',
#   'small',
#   'bowl',
#   'shadow',
#   'yellow',
#   'liquid',
#   'round',
#   'plate',
#   'child',
#   'holding',
#   'spoon',
#   'pink',
#   'gey',
#   'short',
#   'sleeve',
#   'shirt',
#   'napkin',
#   'checkered',
#   'border',
#   'girl',
#   'eats',
#   'food',
#   'being',
#   'dipped',
#   'into',
#   'cup',
#   'worn',
#   'by',
#   'empty',
#   'it',
#   'focuses',
#   'stirring',
#   'long',
#   'hair',
#   'surfboard',
#   'three',
#   'fins',
#   'wetsuit',
#   'ocean',
#   'large',
#   'wave',
#   'crashing',
#   'right',
#   'front',
#   'big',
#   'developing',
#   'back',
#   'standing',
#   'water',
#   'board',
#   'bottom',
#   'suit',
#   's',
#   'wet',
#   'braid',
#   'that',
#   'cap',
#   'waves',
#   'surfing',
#   'shore',
#   'surfer',
#   'pony',
#   'thigh',
#   'deep',
#   'tethered',
#   'her',
#   'leg',
#   'sleeved',
#   'surf',
#   'portion',
#   'wire',
#   'attached',
#   'facing',
#   'she',
#   'ponytail',
#   'wants',
#   'ride',
#   'this',
#   'touching',
#   'zebras',
#   'dirt',
#   'zebra',
#   'wooden',
#   'fence',
#   'chainlink',
#   'inserts',
#   'tree',
#   'branches',
#   'leaves',
#   'an',
#   'enclosed',
#   'area',
#   'walking',
#   'together',
#   'behind',
#   'picket',
#   'beside',
#   'legs',
#   'middle',
#   'roof',
#   'shelter',
#   'have',
#   'stripes',
#   'these',
#   'chain',
#   'link',
#   'pen',
#   'wander',
#   'like',
#   'line',
#   'musketeers',
#   'bent',
#   'fore',
#   'knee',
#   'left',
#   'closest',
#   'wall',
#   'wrought',
#   'iron',
#   'gate',
#   'fronts',
#   'against',
#   'or',
#   'reasonably',
#   'hot',
#   'tin',
#   'sun',
#   'upon',
#   'thinner',
#   'legged',
#   'limber',
#   'seeming',
#   'at',
#   'centre',
#   'z',
#   'gang',
#   'expressions',
#   'calm',
#   'friendly',
#   'very',
#   'familiar',
#   'another',
#   'planks',
#   'group',
#   'high',
#   'meshed',
#   'rough',
#   'declining',
#   'soil',
#   'roofs',
#   'dry',
#   'hanging',
#   'down',
#   'metal',
#   'frames',
#   'forming',
#   'skateboard',
#   'air',
#   'men',
#   'set',
#   'steps',
#   'pair',
#   'shoes',
#   'crossed',
#   'feet',
#   'concrete',
#   'foot',
#   'raised',
#   'leaning',
#   'shorts',
#   'young',
#   'headband',
#   'out',
#   'each',
#   'other',
#   'skatepark',
#   'skate',
#   'park',
#   'ramps',
#   'stairs',
#   'bandana',
#   'resting',
#   'design',
#   'ledge',
#   'step',
#   'stairway',
#   'up',
#   'skating',
#   'mid',
#   'gray',
#   'side',
#   'arm',
#   'bright',
#   'sunny',
#   'day',
#   'benches',
#   'lap',
#   'playing',
#   'baseball',
#   'field',
#   'safety',
#   'net',
#   'player',
#   'logo',
#   'spray',
#   'painted',
#   'uniform',
#   'pants',
#   'falls',
#   'sign',
#   'road',
#   'pathway',
#   'street',
#   'lamp',
#   'octagon',
#   'stop',
#   'four',
#   'way',
#   'intersection',
#   'sidewalk',
#   'trees',
#   'houses',
#   'house',
#   'shadows',
#   'cast',
#   'electric',
#   'wires',
#   'pavement',
#   'power',
#   'lines',
#   'over',
#   'above',
#   'kite',
#   'part',
#   'lighter',
#   'cobble',
#   'stones',
#   'stone',
#   'object',
#   'awe',
#   'inspiring',
#   'city',
#   'filled',
#   'parking',
#   'lot',
#   'ramp',
#   'railing',
#   'sculpture',
#   'building',
#   'structure',
#   'no',
#   'piece',
#   'art',
#   'rounded',
#   'square',
#   'base',
#   'scene',
#   'during',
#   'time',
#   'sculputre',
#   'odd',
#   'seat',
#   'peach',
#   'mat',
#   'leading',
#   'going',
#   'glass',
#   'clear',
#   'children',
#   'trimmed',
#   'grass',
#   'around',
#   'extra',
#   'cat',
#   'bed',
#   'spots',
#   'mattress',
#   'floral',
#   'print',
#   'off',
#   'pillows',
#   'cases',
#   'wood',
#   'unmade',
#   'rear',
#   'cord',
#   'socket',
#   'flower',
#   'leaf',
#   'stem',
#   'purple',
#   'butterfly',
#   'garden',
#   'sunflower',
#   'petals',
#   'butter',
#   'fly',
#   'head',
#   'lowered',
#   'grazing',
#   'flamingos',
#   'distance',
#   'eating',
#   'heads',
#   'eyes',
#   'noses',
#   'was',
#   'taken',
#   'outdoors',
#   'phone',
#   'brick',
#   'bricks',
#   'earth',
#   'car',
#   'sedan',
#   'cargo',
#   'truck',
#   'work',
#   'passenger',
#   'van',
#   'trailer',
#   'talking',
#   'cell',
#   'pillar',
#   'beige',
#   'where',
#   'vehicles',
#   'bordering',
#   'tile',
#   'floor',
#   'columns',
#   'umbrella',
#   'outfit',
#   'center',
#   'from',
#   'open',
#   'lamb',
#   'chops',
#   'broccoli',
#   'chop',
#   'potatoes',
#   'skin',
#   'steamed',
#   'baby',
#   'ribs',
#   'salad',
#   'ceramic',
#   'surface',
#   'charred',
#   'crusted',
#   'spices',
#   'florets',
#   'bit',
#   'tips',
#   'bones',
#   'meat',
#   'shown',
#   'utensils',
#   'inside',
#   'slices',
#   'trim',
#   'vegetables',
#   'sliced',
#   'pieces',
#   'bone',
#   'cooked',
#   'giraffe',
#   'sticking',
#   'giraffes',
#   'low',
#   'bushes',
#   'taller',
#   'slightly',
#   'darker',
#   'spotted',
#   'fur',
#   'animal',
#   'body',
#   'overcast',
#   'overhead',
#   'not',
#   'yet',
#   'full',
#   'bloom',
#   'indicating',
#   'spring',
#   'season',
#   '2',
#   'close',
#   'their',
#   'tails',
#   'well',
#   'feed',
#   'daylight',
#   'grasses',
#   'succulents',
#   'eaten',
#   'patch',
#   'neck',
#   'tee',
#   'plaid',
#   't',
#   'tallest',
#   'cut',
#   'suv',
#   'parked',
#   'markings',
#   'moustache',
#   'bordered',
#   'squares',
#   'vehicle',
#   'nearby',
#   'enjoying',
#   'beer',
#   'posing',
#   'friend',
#   'dress',
#   'lady',
#   'blonde',
#   'burgundy',
#   'cloth',
#   'girls',
#   'striped',
#   'tablecloth',
#   'lattice',
#   'newsboy',
#   'ladies',
#   'smiling',
#   'for',
#   'picture',
#   'guy',
#   'buy',
#   'glasses',
#   'dishes',
#   'divider',
#   'patio',
#   'women',
#   'mexican',
#   'style',
#   'napkins',
#   'blouse',
#   'planes',
#   'flying',
#   'closely',
#   'weather',
#   'few',
#   'fluffy',
#   'chance',
#   'rain',
#   'tennis',
#   'court',
#   'ball',
#   'racket',
#   'racquet',
#   'struck',
#   'netting',
#   'stretching',
#   'get',
#   'play',
#   'hit',
#   'held',
#   'several',
#   'bottles',
#   'counter',
#   'refrigerator',
#   'door',
#   'without',
#   'cabinet',
#   'socks',
#   'gold',
#   'bow',
#   'happy',
#   'freezer',
#   'lower',
#   'stove',
#   'broken',
#   'away',
#   'haired',
#   'upper',
#   'window',
#   'panels',
#   'drawer',
#   'handles',
#   'cooker',
#   'unit',
#   'knob',
#   'controls',
#   'smooth',
#   'vivyl',
#   'laptop',
#   'using',
#   'computer',
#   'chair',
#   'library',
#   'books',
#   'shelf',
#   'rows',
#   'bookshelf',
#   'sweater',
#   'opened',
#   'messy',
#   'framed',
#   'upright',
#   'shelves',
#   'different',
#   'levels',
#   'fingers',
#   'curved',
#   'edges',
#   'purse',
#   'lying',
#   'flat',
#   'tote',
#   'series',
#   'coat',
#   'folded',
#   'laddy',
#   'hooded',
#   'sweatshirt',
#   'used',
#   'stack',
#   'bookshelves',
#   'keyboard',
#   'handbag',
#   'tabletop',
#   'hold',
#   'items',
#   'womans',
#   'shoulders',
#   'apple',
#   'hoodie',
#   'patrons',
#   'pencil',
#   'case',
#   'necktie',
#   'tie',
#   'dogs',
#   'dog',
#   'toppings',
#   'bowling',
#   'alley',
#   'hotdogs',
#   'mustard',
#   'relish',
#   'five',
#   'balls',
#   'return',
#   'serving',
#   'wristband',
#   'tires',
#   'name',
#   'curb',
#   'semi',
#   'traveling',
#   'paving',
#   'windows',
#   'chimney',
#   'rail',
#   'skateboarding',
#   'through',
#   'arms',
#   'extending',
#   'staircase',
#   'cracks',
#   'thick',
#   'stair',
#   'varying',
#   'shades',
#   'discolored',
#   'areas',
#   'handrail',
#   'apartment',
#   'railroad',
#   'freight',
#   'train',
#   'tracks',
#   'construction',
#   'site',
#   'surrounding',
#   'foreground',
#   'section',
#   'track',
#   'motion',
#   'only',
#   'shot',
#   'cars',
#   'materials',
#   'growing',
#   'them',
#   'workers',
#   'outside',
#   'dump',
#   'unloading',
#   'hill',
#   'bush',
#   'flowers',
#   'decoration',
#   'triangles',
#   'intermingled',
#   'w',
#   'flowered',
#   'smoke',
#   'damage',
#   'possible',
#   'graffiti',
#   'dripped',
#   'decayed',
#   'along',
#   'earthmoving',
#   'equipment',
#   'worker',
#   'dude',
#   'between',
#   'grassy',
#   'laptops',
#   'listening',
#   'headphones',
#   'having',
#   'conversation',
#   'paper',
#   'handicap',
#   'scooter',
#   'indoors',
#   'hands',
#   'ears',
#   'looking',
#   'booklets',
#   'trying',
#   'listen',
#   'something',
#   'sofas',
#   'spheres',
#   'cake',
#   'support',
#   'housing',
#   'plant',
#   'container',
#   'frosting',
#   'covered',
#   'circular',
#   'face',
#   'refracting',
#   'sunlight',
#   'platter',
#   'opening',
#   'display',
#   'roughly',
#   'frosted',
#   'stand',
#   'mixing',
#   'indoor',
#   'basil',
#   'pot',
#   'eggs',
#   'headlights',
#   'windshield',
#   'gavel',
#   'poles',
#   'far',
#   'seen',
#   'yard',
#   'built',
#   'bumpers',
#   '7',
#   'total',
#   'trian',
#   'gravel',
#   'sets',
#   'snow',
#   'huge',
#   'snowboard',
#   'completely',
#   'dust',
#   'snowboarder',
#   'jumping',
#   'night',
#   'skies',
#   'skis',
#   'turned',
#   'covering',
#   'evening',
#   'making',
#   'jump',
#   'strap',
#   'doing',
#   'tricks',
#   'boy',
#   'shiny',
#   'balloons',
#   'tied',
#   'king',
#   'crown',
#   'gathered',
#   'helium',
#   'poster',
#   'crowns',
#   'can',
#   'be',
#   'dessert',
#   'served',
#   'kids',
#   'slice',
#   'paint',
#   'blond',
#   'strings',
#   'cutting',
#   'pizza',
#   'bungee',
#   'box',
#   'rope',
#   'somethings',
#   'cement',
#   'some',
#   'designs',
#   'closed',
#   'graphic',
#   'slicing',
#   'sauce',
#   'cheese',
#   'spinach',
#   'workstation',
#   'cutter',
#   'chairs',
#   'desk',
#   'drawings',
#   'trellis',
#   'driveway',
#   'planter',
#   'arch',
#   'vine',
#   'carport',
#   'sprinklers',
#   'surround',
#   'stirred',
#   'cloudy',
#   'wavy',
#   'sandy',
#   'rocks',
#   'dashes',
#   'signpost',
#   'dotted',
#   'asphalt',
#   'sides',
#   'peoples',
#   'image',
#   'fast',
#   'joint',
#   'control',
#   'label',
#   'thumb',
#   'nail',
#   'remote',
#   'fingertips',
#   'arrows',
#   'furniture',
#   'device',
#   'rectangle',
#   'shaped',
#   'palm',
#   'samsung',
#   'pad',
#   'show',
#   'blurry',
#   'mp3',
#   'skyline',
#   'cranes',
#   'old',
#   'sailing',
#   'vessel',
#   'dock',
#   'boat',
#   'lighthouse',
#   'harbor',
#   'ship',
#   'pier',
#   'hatchback',
#   'crane',
#   'overhanging',
#   'walkway',
#   'seaport',
#   'pedestrians',
#   'tower',
#   'while',
#   'running',
#   'throwing',
#   'frisbee',
#   'shirtless',
#   'catch',
#   'fake',
#   'cow',
#   'jersey',
#   'milk',
#   'replica',
#   'model',
#   'statue',
#   'miniature',
#   'glowing',
#   'loose',
#   'cable',
#   'darkened',
#   'fenced',
#   'mural',
#   'painting',
#   'lighted',
#   'doll',
#   'printed',
#   'circles',
#   'quilt',
#   'giving',
#   'thumbs',
#   'patchwork',
#   'jointed',
#   'i',
#   'love',
#   'new',
#   'york',
#   'frame',
#   'eye',
#   'partly',
#   'says',
#   'reddish',
#   'toy',
#   'plat',
#   'laying',
#   'messed',
#   'skateboarder',
#   'does',
#   'trick',
#   'skater',
#   'male',
#   'adidas',
#   'bare',
#   'fences',
#   'tilted',
#   'who',
#   'fallen',
#   'snowsuit',
#   'ski',
#   'fell',
#   'trails',
#   'coming',
#   'trail',
#   'wiped',
#   'skiers',
#   'falling',
#   'skiing',
#   'skier',
#   'slope',
#   'human',
#   'ice',
#   'thorny',
#   'less',
#   'trunk',
#   'mane',
#   'rump',
#   'forward',
#   'toward',
#   'horse',
#   'nose',
#   'animals',
#   'itself',
#   'wilderness',
#   'woods',
#   'twig',
#   'camera',
#   'its',
#   'vertical',
#   'horizontal',
#   'leafy',
#   'clumpy',
#   'lush',
#   'hazy',
#   'fern',
#   'piano',
#   'room',
#   'watching',
#   'houseplant',
#   'barrels',
#   'couple',
#   'wine',
#   'tasting',
#   'button',
#   'kegs',
#   'bottle',
#   'chilling',
#   'dip',
#   'chips',
#   'bunch',
#   'stacked',
#   'sweaty',
#   'boarding',
#   'rink',
#   'sleeves',
#   'thin',
#   'chest',
#   'guys',
#   'crossing',
#   'lettering',
#   'pagoda',
#   'jeans',
#   'digital',
#   'rolled',
#   'crosswalk',
#   ...],
#  'word2idx': {'fawn': 14282,
#   'splatered': 28953,
#   'woodd': 28083,
#   'woode': 3302,
#   'woodn': 33006,
#   'ampitheatre': 27689,
#   'woods': 959,
#   'hangind': 9090,
#   'hanginf': 5409,
#   'hanging': 248,
#   'woody': 2269,
#   'openen': 27970,
#   'comically': 26514,
#   'spidery': 32759,
#   'tenins': 32615,
#   'crossbag': 17079,
#   'canes': 24935,
#   'sheephas': 16442,
#   'bicylces': 30179,
#   'feahers': 22774,
#   'caned': 16174,
#   'crossbar': 22710,
#   'driied': 18566,
#   'bocks': 13111,
#   'sculputre': 356,
#   'lings': 37402,
#   'bratislava': 36684,
#   'rawhide': 27452,
#   'antoher': 27744,
#   'hyfrant': 28290,
#   'bringing': 7225,
#   'seperaters': 34174,
#   'revelers': 17451,
#   'wooded': 4711,
#   'broiler': 12794,
#   'wooden': 179,
#   'retreivor': 24806,
#   'woodem': 28671,
#   'mustaching': 37216,
#   'broiled': 25281,
#   'circuitry': 37437,
#   'crotch': 5911,
#   'stereotypical': 29038,
#   'sailboarder': 20450,
#   'guardsmen': 13644,
#   'sooty': 33901,
#   'gaskets': 29455,
#   'snuggles': 12592,
#   'scrapes': 19538,
#   'scraper': 43,
#   'bannister': 4328,
#   'bearfoot': 35828,
#   '275': 36415,
#   '276': 35203,
#   '277': 34126,
#   'scraped': 10180,
#   'snuggled': 22512,
#   'inanimate': 27653,
#   'semicircular': 13599,
#   'numeras': 25098,
#   'bikeshiny': 27694,
#   'cooking': 1206,
#   'graing': 31342,
#   'outfielders': 31816,
#   'numeral': 1768,
#   'pawed': 12600,
#   'rbead': 6974,
#   'mccutchen': 32142,
#   'widget': 23341,
#   'athat': 38461,
#   'crouch': 12758,
#   '9258': 8077,
#   'sattle': 8880,
#   'sunbeams': 19587,
#   'srubs': 15996,
#   'ilned': 14767,
#   'erum': 14451,
#   'chine': 38649,
#   'headna': 21057,
#   'china': 5522,
#   'gambrel': 8598,
#   'motorolla': 29495,
#   'baldy': 30340,
#   'suntan': 26820,
#   'natured': 24687,
#   'kids': 797,
#   'spottd': 27126,
#   'climbed': 22486,
#   'oxymoron': 25995,
#   'natures': 34045,
#   'talbe': 16456,
#   'spotty': 10303,
#   'climber': 14122,
#   'golden': 1915,
#   'cobblers': 24889,
#   'kethcup': 33491,
#   'projection': 3884,
#   'lengthed': 19681,
#   'loudoun': 30360,
#   'miniva': 31611,
#   'orangish': 10872,
#   'stero': 28112,
#   'stern': 6349,
#   'constuct': 33243,
#   'agassi': 35086,
#   'marbel': 12723,
#   'music': 7330,
#   'grahams': 25455,
#   'ungulates': 37699,
#   'cramic': 38555,
#   'diswasher': 11577,
#   'asuit': 35101,
#   'eear': 33519,
#   'yahoo': 15507,
#   'trimwork': 23954,
#   'copse': 8106,
#   'intake': 21580,
#   'mullions': 12060,
#   'locked': 5118,
#   'jumbling': 27978,
#   'heathland': 18640,
#   'locker': 6366,
#   'locket': 21651,
#   'sandier': 17933,
#   'matilda': 21990,
#   'zinnias': 37009,
#   'wand': 12221,
#   'pints': 28271,
#   'criscrossing': 37494,
#   'pooper': 2979,
#   'beansprout': 39030,
#   'sunrays': 1393,
#   'cookers': 6100,
#   'pinto': 12156,
#   'mcmuffin': 10789,
#   'scooner': 37826,
#   'windshileds': 27208,
#   'travel': 1506,
#   'copious': 14396,
#   'cutback': 39162,
#   'barstools': 9987,
#   'topings': 14268,
#   'neckof': 26449,
#   'stoller': 26267,
#   'dinosaurs': 15270,
#   'modest': 4540,
#   'wristlet': 26153,
#   'promotion': 27410,
#   'colorfully': 2727,
#   'tulip': 6871,
#   '18th': 16956,
#   'sieko': 33012,
#   'concoction': 30277,
#   'farmlands': 17094,
#   'romper': 13823,
#   'fowers': 22102,
#   'snugly': 35228,
#   'puling': 18174,
#   'whizzing': 15400,
#   'sneakered': 18999,
#   'activating': 15449,
#   'playhouse': 18953,
#   'fir': 4915,
#   'iscolorfull': 14626,
#   'fit': 7132,
#   'labratory': 18378,
#   'screaming': 9365,
#   'fix': 5458,
#   'inan': 14706,
#   'bulding': 6279,
#   'fig': 3299,
#   'fid': 19410,
#   'fie': 19199,
#   'jumpskirt': 29878,
#   'fin': 2372,
#   'fil': 8868,
#   'fim': 38258,
#   'luncbox': 36722,
#   'bristle': 23283,
#   'chawton': 10793,
#   'municipality': 30295,
#   'nlond': 31245,
#   'effects': 8763,
#   'rudders': 20006,
#   'fiuzzy': 19263,
#   'sixteen': 7197,
#   'undeveloped': 27210,
#   'conner': 30289,
#   'defecate': 34890,
#   'vilot': 31170,
#   'barton': 27998,
#   'foregin': 31910,
#   'bartop': 26496,
#   'arror': 25482,
#   'arrow': 2079,
#   'estavayer': 36247,
#   'development': 32197,
#   'telescope': 12697,
#   'sandbars': 35638,
#   'voyeur': 15741,
#   'mocrophone': 35494,
#   'parasites': 21413,
#   'childen': 14011,
#   'grapefruits': 9329,
#   'buttercups': 24393,
#   'thached': 38052,
#   'smirk': 13548,
#   'dge': 22631,
#   'mason': 3955,
#   'trucnk': 9706,
#   'encourage': 3480,
#   'adapt': 9701,
#   'guitarists': 27945,
#   'cementery': 25072,
#   'sorrouded': 25605,
#   'mbrella': 15122,
#   'stamping': 37964,
#   'sheetrock': 30087,
#   'orrange': 10078,
#   'underfoot': 17601,
#   'beneth': 38613,
#   'pumpkins': 3139,
#   'pileof': 13482,
#   'chlorine': 7835,
#   'silent': 23935,
#   'stuffedpuppy': 29749,
#   'redhair': 22073,
#   'lshaped': 34695,
#   'disturbed': 11268,
#   'bannanas': 9313,
#   'chiars': 26997,
#   'visibble': 33095,
#   'breed': 6869,
#   'orance': 22895,
#   'disfigured': 26408,
#   'gizalles': 36526,
#   'kfc': 15189,
#   'chevron': 16290,
#   'lomitas': 34284,
#   'usbs': 21022,
#   'metakl': 23670,
#   'sittinginside': 36271,
#   'masted': 6764,
#   'suitable': 32677,
#   'renovated': 17327,
#   'service': 3630,
#   'backcpack': 36361,
#   'reuben': 26072,
#   'needed': 13158,
#   'master': 1048,
#   'critter': 10479,
#   'fuzziness': 11633,
#   'pockest': 28606,
#   'cisterns': 35803,
#   'swish': 10538,
#   'mutilated': 37123,
#   'caricture': 37523,
#   'hindsville': 22001,
#   'horrible': 21147,
#   'positively': 30343,
#   'spayed': 11017,
#   '271': 22461,
#   'mulicolored': 26781,
#   'handcuffs': 9569,
#   'idly': 19343,
#   'regulator': 36105,
#   'idle': 9876,
#   'twobottles': 17903,
#   'friend': 512,
#   'snowboaarding': 37643,
#   'blackbag': 20242,
#   'shampoos': 11695,
#   'feeling': 14315,
#   'idli': 37497,
#   'dozer': 3812,
#   'longs': 13868,
#   'hsoe': 21546,
#   'endtable': 9240,
#   'hetrosexual': 15104,
#   'peacoat': 11188,
#   'brawny': 36742,
#   'urinate': 33158,
#   'thoothbrush': 33920,
#   'dozen': 10562,
#   'birght': 29833,
#   'wholesome': 25516,
#   'toulet': 14437,
#   'paramedics': 26294,
#   'poms': 13710,
#   'vga': 20133,
#   'racers': 9647,
#   'toothed': 7693,
#   'unibuss': 34942,
#   'doughuts': 36262,
#   'nthat': 35172,
#   'committing': 33577,
#   'unknow': 30950,
#   'sugarcane': 7138,
#   'buildgin': 38989,
#   'veniam': 17978,
#   'moutn': 37682,
#   'mouth': 1484,
#   'icloud': 36551,
#   'expanse': 4051,
#   'singer': 14022,
#   'backgroound': 21167,
#   'toothbush': 29543,
#   'tech': 3603,
#   'prevention': 19838,
#   'scream': 29009,
#   'screan': 10627,
#   'saying': 1982,
#   'whaped': 26134,
#   'braising': 21815,
#   'caging': 25837,
#   'teresa': 23241,
#   'brocolii': 32110,
#   'padded': 1576,
#   'fennel': 12146,
#   'pontoons': 11682,
#   'balence': 24667,
#   'doilee': 31589,
#   'orleans': 14460,
#   'flowers': 692,
#   'excavator': 14126,
#   'rectagular': 35401,
#   'overgown': 22583,
#   'clicker': 1252,
#   'bliss': 9831,
#   'rick': 13611,
#   'rich': 7732,
#   'rice': 5919,
#   'doiley': 12055,
#   'plate': 104,
#   'bunchof': 7598,
#   'veggetable': 26057,
#   'platn': 38932,
#   'designing': 38512,
#   'umbilical': 36932,
#   'ceil': 5231,
#   'platt': 10945,
#   'donairs': 19037,
#   'caribg': 16966,
#   'cment': 29201,
#   'altogether': 14999,
#   'toungue': 30987,
#   'platz': 38414,
#   'jaguar': 38859,
#   'treesand': 32816,
#   'nicely': 2192,
#   'boarder': 1167,
#   'kanine': 36425,
#   'pretzel': 10880,
#   'amaroon': 38270,
#   'patch': 494,
#   'eyelids': 12620,
#   'shocks': 8641,
#   'boarded': 11769,
#   'skechers': 35003,
#   'heirloom': 15960,
#   'waterbottle': 11122,
#   'dandilion': 13803,
#   'pinot': 33861,
#   'wayter': 25878,
#   'mircophone': 35472,
#   'trivet': 14353,
#   'suticase': 14865,
#   'lots': 1078,
#   'irl': 21213,
#   'cordoned': 15880,
#   'ire': 14766,
#   'extend': 5216,
#   'nature': 5631,
#   'snowbard': 18410,
#   'lapping': 13464,
#   'wheelbarrow': 3856,
#   'tendons': 23539,
#   'bisleri': 21846,
#   'degnans': 13277,
#   'airflow': 29421,
#   'veep': 11434,
#   'warching': 32209,
#   'veer': 13998,
#   'importantce': 19092,
#   'heating': 5126,
#   'incense': 20106,
#   'levitating': 3726,
#   'shweatshirt': 12466,
#   'lookin': 6137,
#   'boatlike': 37668,
#   'fearlessly': 33503,
#   'ariel': 28820,
#   'tmnt': 38861,
#   'decends': 22866,
#   'blonds': 13731,
#   'blondo': 27788,
#   'fondled': 34842,
#   'underpants': 27275,
#   'stoneless': 36337,
#   'brindle': 3732,
#   'blonde': 515,
#   'pasteled': 34622,
#   'chino': 31443,
#   'gasme': 31262,
#   'fre': 30625,
#   'foood': 29674,
#   'union': 11255,
#   'voluptates': 17969,
#   'fri': 36582,
#   'grotto': 30023,
#   'fro': 23567,
#   'studious': 37960,
#   'wlking': 31574,
#   'muck': 15137,
#   'much': 1554,
#   'voluptatem': 17997,
#   'unleavened': 29981,
#   'fry': 3782,
#   'tallest': 499,
#   'distinctio': 17967,
#   'obese': 10197,
#   'enose': 37033,
#   'spit': 16450,
#   'conifers': 15860,
#   'davy': 31723,
#   'dave': 33463,
#   'spin': 1290,
#   'professionally': 9396,
#   'paraglider': 38616,
#   'bmetal': 4831,
#   'convertable': 12151,
#   'applese': 14752,
#   'elaborate': 13488,
#   'ss266': 38634,
#   'canoeing': 13481,
#   'taxicabs': 21329,
#   'ield': 31126,
#   'kohl': 37194,
#   'conditioned': 30995,
#   'eighteen': 3505,
#   'conditioner': 2526,
#   'sbowboard': 14290,
#   'hone': 6899,
#   'memorial': 5690,
#   'hona': 21985,
#   'portobella': 38977,
#   'portobello': 16114,
#   'plaate': 39254,
#   'honk': 3788,
#   'spews': 33829,
#   'split': 1694,
#   'briney': 28491,
#   'watcing': 23661,
#   'boiled': 3036,
#   'flipflops': 6768,
#   'blazier': 19844,
#   'crosstie': 21143,
#   '126th': 22469,
#   'dorminant': 20701,
#   'qdoba': 34306,
#   'gerflor': 20410,
#   'boiler': 11051,
#   'supper': 19708,
#   'engin': 12006,
#   'advertizement': 12946,
#   'midsized': 37368,
#   'petaled': 33163,
#   'labrotory': 12990,
#   'maoutain': 35368,
#   'levelor': 26708,
#   'academic': 28709,
#   'goofing': 6036,
#   'corporate': 9573,
#   'plaque': 1766,
#   'bellow': 10888,
#   'appropriately': 35321,
#   'topography': 36861,
#   'waterboard': 8923,
#   'stne': 32854,
#   'stnd': 18717,
#   'portrayed': 32153,
#   'lasso': 2498,
#   'ham': 3111,
#   'han': 30252,
#   'had': 2063,
#   'rx405': 22987,
#   'hay': 4568,
#   'waffels': 17544,
#   'beloved': 19039,
#   'duffel': 3531,
#   'har': 10750,
#   'has': 14,
#   'hat': 26,
#   'fieled': 21072,
#   'hav': 25078,
#   'municipal': 21195,
#   'reuseable': 8945,
#   'shadoe': 31836,
#   'confection': 29120,
#   'shadof': 19013,
#   'cicrcle': 25640,
#   'indicative': 33363,
#   'clustered': 10151,
#   'shadow': 100,
#   'flotsam': 24991,
#   'wreckage': 22857,
#   'overgrazed': 9708,
#   'goround': 31300,
#   'alice': 25899,
#   'gangplank': 12771,
#   'festivities': 6634,
#   'bemch': 39036,
#   'beneficial': 13159,
#   'crowd': 1163,
#   'cruisers': 24885,
#   'czech': 23906,
#   'crown': 788,
#   'begin': 22584,
#   'captive': 7175,
#   'karmeliet': 35663,
#   'billboard': 4677,
#   'profuct': 20943,
#   'botton': 21311,
#   'bottom': 147,
#   'propelle': 34735,
#   'propella': 25023,
#   'plucked': 30464,
#   'refridge': 30274,
#   'frui': 14506,
#   'treadmill': 34388,
#   'plucker': 37783,
#   'opponents': 30515,
#   'completly': 18706,
#   'barcode': 9614,
#   'binder': 10009,
#   'starring': 16208,
#   'stokes': 17777,
#   'benches': 292,
#   'powerized': 22996,
#   'pillos': 29712,
#   'stoked': 32096,
#   'bluebaseball': 22744,
#   'acow': 22824,
#   'aregreen': 18908,
#   'cicrles': 29396,
#   'beinge': 11359,
#   'maxwell': 13635,
#   'dyson': 21230,
#   'honeymoon': 32098,
#   'beings': 19266,
#   'mangos': 17932,
#   'overpassing': 31956,
#   'shoots': 7885,
#   'fabric': 1667,
#   'altitude': 10490,
#   'anoher': 22794,
#   'tame': 36594,
#   'grafiteed': 35407,
#   'grasping': 2224,
#   'greatness': 20548,
#   'rapes': 9801,
#   'avocados': 14779,
#   'grooms': 21537,
#   '30s': 27589,
#   'spurting': 2874,
#   'buttoning': 2867,
#   'denoting': 2725,
#   'verde': 27932,
#   'peperoni': 14492,
#   'oof': 25012,
#   'paneled': 1963,
#   'layig': 25585,
#   'whute': 24782,
#   'rippling': 1061,
#   'arrays': 19455,
#   'peson': 7140,
#   'dinnertable': 21737,
#   'chandleir': 30332,
#   'darking': 4397,
#   'nicest': 31360,
#   'servings': 6303,
#   'smashed': 17389,
#   'chihucaha': 24008,
#   'unfabric': 29035,
#   'celtape': 20468,
#   'passenger': 415,
#   'ornaments': 2915,
#   'outddoors': 13703,
#   'livestrong': 37673,
#   'grabble': 38207,
#   'calzones': 17484,
#   'directuion': 1330,
#   'bedsheet': 1238,
#   'windshiild': 31221,
#   'females': 4765,
#   'triangles': 694,
#   'burntish': 38612,
#   'microwaving': 20004,
#   'retractible': 33907,
#   'crowns': 792,
#   'sandaled': 8363,
#   'serous': 8908,
#   'role': 19921,
#   'macaroon': 29340,
#   'vegetative': 32614,
#   'roll': 1860,
#   'besifd3': 39277,
#   'intend': 31425,
#   'palms': 2903,
#   'edog': 35484,
#   'ointment': 28978,
#   'transported': 3015,
#   'surfboar': 5222,
#   'televsion': 2631,
#   'surfboat': 30058,
#   'smelling': 5889,
#   'variable': 23520,
#   'transporter': 4354,
#   'explosions': 15017,
#   'shootout': 33065,
#   'windsocks': 24695,
#   'birddie': 36699,
#   'miuntes': 29236,
#   'jmi': 32084,
#   'overturned': 15685,
#   'gown': 4556,
#   'childs': 2080,
#   'cincinnati': 14485,
#   'couds': 7418,
#   'chain': 201,
#   '2x4s': 18256,
#   'coudy': 10172,
#   'oktopus': 24483,
#   'childi': 17022,
#   'chair': 589,
#   'volly': 34318,
#   'chait': 8438,
#   'coudh': 34475,
#   'ballet': 10193,
#   'baller': 22506,
#   'timbered': 19184,
#   'crates': 1691,
#   'crater': 27288,
#   'mache': 10369,
#   'balled': 15346,
#   'larg': 8461,
#   'windshields': 6741,
#   'comfertor': 29888,
#   'flatbed': 4470,
#   'powedering': 7483,
#   'shelvs': 34050,
#   'skateboad': 10788,
#   'olympus': 29764,
#   'choice': 3289,
#   'embark': 32377,
#   'gloomy': 9141,
#   'ghostbusters': 8604,
#   'knapsack': 15687,
#   'stays': 13387,
#   'rechargable': 24759,
#   'exact': 14754,
#   'minute': 1317,
#   'skateboar': 28224,
#   'notations': 34150,
#   'cooks': 8826,
#   'reining': 18660,
#   'refueler': 30595,
#   'cooky': 34716,
#   'ashtry': 30990,
#   'minnie': 10605,
#   'skewed': 20711,
#   'refueled': 16721,
#   'cooke': 22562,
#   'cooki': 34325,
#   'skewer': 13353,
#   'meadow': 2423,
#   'trails': 936,
#   'shirtl': 24171,
#   'scen': 31453,
#   'specked': 18116,
#   'overized': 34556,
#   'gnawed': 30306,
#   'chopping': 2779,
#   'shirts': 1596,
#   'shirtq': 19091,
#   'adorns': 31684,
#   'bagging': 10878,
#   'headset': 6597,
#   'wodds': 28436,
#   'antecubital': 36880,
#   'celebrated': 14731,
#   'grounf': 36438,
#   'polygonal': 34606,
#   'wayward': 23907,
#   'tils': 37618,
#   'ground': 50,
#   'celebrates': 23939,
#   'unintentionally': 29965,
#   '303': 34504,
#   'climbs': 9185,
#   'plucking': 33480,
#   'address': 8152,
#   '165136': 30659,
#   '307': 31968,
#   'dusts': 25090,
#   'dusty': 3451,
#   'impacted': 31206,
#   'workpants': 16121,
#   'queue': 4564,
#   'accomplished': 21834,
#   'pathyway': 25486,
#   'sprouted': 19019,
#   'eyeglasse': 34070,
#   'britsles': 32082,
#   'porceain': 33207,
#   'agirrafe': 38421,
#   'exitting': 20214,
#   'eteched': 34157,
#   'inquisitively': 30378,
#   'ltraffic': 9030,
#   'cornbeef': 10271,
#   'screenporch': 34548,
#   'working': 2056,
#   'hyatt': 33930,
#   'bouys': 14123,
#   'raquetball': 33276,
#   'opposed': 24492,
#   'ree': 24004,
#   'burgendy': 23454,
#   '164th': 37501,
#   'tined': 14694,
#   'lmpa': 24612,
#   'manman': 37331,
#   'tundra': 8576,
#   'sierra': 32936,
#   'consoles': 5021,
#   'galzed': 18458,
#   'tines': 9788,
#   'licourice': 4889,
#   'brociolli': 33010,
#   'termac': 23697,
#   'riders': 1468,
#   'wve': 38789,
#   'lowercase': 28165,
#   'titanium': 28001,
#   'multen': 27795,
#   'originally': 21638,
#   'woeden': 38298,
#   'omelete': 17913,
#   'binsunder': 29902,
#   'following': 2531,
#   'zippers': 4779,
#   'surfobard': 38053,
#   'admired': 18733,
#   'want': 4486,
#   'outlilng': 28543,
#   'mirrors': 2599,
#   'stetson': 20429,
#   'piolice': 30309,
#   'mailboxes': 4506,
#   'palyig': 17730,
#   'parachute': 2548,
#   'locks': 9049,
#   'outhouses': 21232,
#   'stiteched': 35683,
#   'locale': 36171,
#   'mirroro': 18220,
#   'cleaer': 28954,
#   'usng': 9809,
#   'listens': 16398,
#   'septic': 2458,
#   'poloar': 5924,
#   'atasty': 39169,
#   'nightclothes': 33279,
#   'cirlces': 29397,
#   'flagpost': 36203,
#   'pohnes': 34867,
#   'liverpool': 12383,
#   'fueled': 7344,
#   'onlette': 17914,
#   'temperate': 22047,
#   'pulley': 2293,
#   'surfing': 155,
#   'mangy': 12358,
#   'bracelett': 29698,
#   'puller': 32798,
#   'clck': 27673,
#   'quadrant': 37268,
#   'underneatht': 36503,
#   'sandbox': 31071,
#   'mango': 7285,
#   'untensils': 7506,
#   'swollen': 23659,
#   'tracktor': 36278,
#   'mange': 37526,
#   'wolves': 4687,
#   'pulled': 1586,
#   'foset': 34288,
#   'wastepaper': 33854,
#   'whitetiled': 30924,
#   'feedin': 26237,
#   'webpage': 8187,
#   'years': 9770,
#   'yearn': 23367,
#   'datestamp': 27780,
#   'celar': 28119,
#   'ovals': 6423,
#   'jib': 15195,
#   'milked': 23357,
#   'knelled': 36611,
#   'jim': 23534,
#   'ovale': 25890,
#   'grazingon': 13735,
#   'suspension': 5990,
#   'troubled': 8499,
#   'browwn': 32566,
#   'apron': 2785,
#   'civilian': 14739,
#   'sorter': 27743,
#   'mouldings': 27118,
#   'drilling': 5671,
#   'sorted': 19088,
#   'frontage': 4893,
#   'hickory': 16119,
#   'didn': 20108,
#   'pealing': 13321,
#   'fisherman': 7825,
#   'apia': 11932,
#   'photoshoot': 21833,
#   'quartet': 29611,
#   'backplate': 4611,
#   'retrieve': 18452,
#   'diffrents': 32741,
#   'bursting': 9798,
#   'coutdoors': 37694,
#   'salade': 38673,
#   'receipt': 11754,
#   'frames': 251,
#   'sponsor': 7944,
#   'entering': 2892,
#   'chatcher': 32413,
#   'salads': 17794,
#   'knofe': 6773,
#   'leeves': 30013,
#   'cubicals': 13331,
#   'seriously': 27084,
#   'internet': 7404,
#   'wisker': 12728,
#   'curbs': 8828,
#   'hairdresser': 22729,
#   'complicated': 5556,
#   'grandma': 4369,
#   'umbtrella': 12047,
#   'brasil': 23134,
#   'fottball': 26010,
#   'wrong': 6721,
#   'benching': 24716,
#   'esquarian': 30263,
#   'aboard': 13830,
#   'socking': 31133,
#   'poecelain': 20716,
#   'emotion': 23955,
#   'afarm': 33798,
#   'spoked': 6131,
#   'saving': 13214,
#   'symmetry': 37301,
#   'onm': 36537,
#   'onb': 36098,
#   'ona': 11494,
#   'westlake': 11642,
#   'ong': 13575,
#   'menzie': 32173,
#   'one': 57,
#   'pasteries': 11567,
#   'mignon': 26711,
#   'spokes': 1533,
#   'periodical': 13785,
#   'tamarc': 36088,
#   'ons': 15068,
#   'onp': 10924,
#   'onq': 36848,
#   'veldt': 16311,
#   'ont': 1528,
#   'nubian': 12510,
#   'mjaor': 9543,
#   'peperroni': 21749,
#   'lingering': 8402,
#   'herde': 29690,
#   'shawl': 2148,
#   'tombstones': 11077,
#   'snatch': 23969,
#   'srufing': 19886,
#   'arround': 12353,
#   'shaws': 32479,
#   'herds': 10076,
#   'squiggles': 14016,
#   'elephabts': 34518,
#   'backspash': 22983,
#   'browncolor': 36656,
#   'crossroads': 13435,
#   'unheated': 36997,
#   'lillies': 20667,
#   'wandering': 7415,
#   'jewely': 13883,
#   'sumptuous': 27798,
#   'turned': 775,
#   'locations': 10112,
#   'jewels': 12154,
#   'cbls': 22281,
#   'uninterrupted': 21242,
#   'turner': 4672,
#   'borough': 20620,
#   '86260': 17524,
#   'tenning': 39014,
#   'pekingese': 13343,
#   'pounded': 37679,
#   'fashionable': 16049,
#   'warriors': 7657,
#   'zoo': 1336,
#   'elephent': 20655,
#   'pimple': 9579,
#   'lesfy': 33543,
#   'printer': 6552,
#   'opposite': 1481,
#   'buffer': 24304,
#   'spewing': 11624,
#   'buffet': 3491,
#   'afixed': 37400,
#   'printed': 902,
#   'bassball': 21926,
#   'buffed': 30470,
#   'thsi': 39232,
#   'mitas': 35973,
#   'phil': 29159,
#   'thse': 10084,
#   'alaminos': 30405,
#   'istanbul': 32561,
#   'delicius': 36016,
#   'theadult': 9948,
#   'wynd': 13610,
#   'wiong': 14031,
#   'fecal': 34464,
#   'elan': 25331,
#   'inconsistent': 27303,
#   'aggressive': 14143,
#   'lungin': 26318,
#   'jerey': 36614,
#   'kateboarder': 37484,
#   'althelic': 37418,
#   'dounuts': 31267,
#   'guarded': 4245,
#   'suitcases': 2045,
#   'tilting': 7399,
#   'balconies': 2344,
#   'simplistic': 30699,
#   'awaiting': 5335,
#   'bathwater': 5075,
#   'tiki': 20627,
#   'asnd': 28350,
#   'tortilla': 2819,
#   'tike': 35100,
#   'vision': 5042,
#   'camode': 36843,
#   'enthralled': 35201,
#   'mountans': 18901,
#   'attenuated': 34902,
#   'driveways': 37179,
#   'carhartt': 24715,
#   'impressions': 21136,
#   '835': 37431,
#   'alarming': 38284,
#   'sponsorship': 4179,
#   'sermoneta': 38998,
#   'aiguillette': 35778,
#   'moons': 9927,
#   'enjoys': 9698,
#   'googiest': 21637,
#   'suculant': 35500,
#   'mosstly': 36496,
#   'medio': 38608,
#   'marietta': 28613,
#   'awards': 11182,
#   'pluck': 37838,
#   'menacing': 26926,
#   'motorcycyles': 29517,
#   'caat': 21795,
#   'caar': 34379,
#   'concentrated': 6762,
#   'busting': 30852,
#   'circumference': 12177,
#   'majestically': 11022,
#   'flipped': 7153,
#   'pocodots': 3641,
#   's': 149,
#   'workplace': 20531,
#   'concentrates': 26960,
#   'grooming': 14620,
#   'furnitures': 29017,
#   'potstickers': 12816,
#   'motorcyl': 27065,
#   ...}}

# %%
import json
import numpy as np
import torch
data = json.load(open(output_dir+'inverse_weight.json'))
weight = torch.zeros(151)
for idx, k in enumerate(data['object'].keys()):
    weight[idx + 1] = data['object'][k]

# %%
print data['object'].keys()
# Out:
# [u'kite', u'pant', u'laptop', u'paper', u'shoe', u'chair', u'ground', u'tire', u'cup', u'sky', u'bench', u'tail', u'bike', u'board', u'hat', u'skier', u'plate', u'woman', u'handle', u'food', u'bear', u'wave', u'giraffe', u'background', u'desk', u'foot', u'shadow', u'lady', u'button', u'glove', u'bag', u'sand', u'nose', u'rock', u'sidewalk', u'motorcycle', u'fence', u'people', u'house', u'sign', u'hair', u'street', u'bed', u'mirror', u'logo', u'girl', u'arm', u'flower', u'leaf', u'clock', u'dirt', u'hill', u'bird', u'umbrella', u'leg', u'reflection', u'water', u'sink', u'trunk', u'post', u'tower', u'box', u'boy', u'cow', u'skateboard', u'pillow', u'road', u'wall', u'number', u'pole', u'table', u'boat', u'sheep', u'horse', u'eye', u'top', u'bush', u'window', u'vehicle', u'brick', u'banana', u'ceiling', u'door', u'shelf', u'glass', u'cloud', u'train', u'child', u'line', u'ear', u'neck', u'ski', u'cap', u'tree', u'roof', u'cat', u'cake', u'grass', u'zebra', u'toilet', u'head', u'bus', u'player', u'airplane', u'face', u'car', u'helmet', u'shirt', u'floor', u'headlight', u'bowl', u'snow', u'couch', u'field', u'lamp', u'book', u'branch', u'elephant', u'tile', u'beach', u'pizza', u'wheel', u'picture', u'plant', u'sandwich', u'mountain', u'track', u'spot', u'hand', u'plane', u'mouth', u'stripe', u'letter', u'vase', u'man', u'building', u'short', u'surfboard', u'phone', u'light', u'counter', u'dog', u'ocean', u'jacket', u'person', u'part', u'truck', u'bottle', u'jean', u'wing']

# %%
weight
# Out:
#  0.0000
#  1.4329
#  1.0296
#  1.7146
#  1.8367
#  1.0488
#  1.1460
#  0.6880
#  1.4560
#  1.8312
#  0.5888
#  1.1075
#  1.0165
#  1.2780
#  1.7301
#  0.9201
#  1.7588
#  0.8832
#  0.5033
#  1.7146
#  1.3540
#  1.0739
#  1.4024
#  0.7616
#  1.2884
#  1.7758
#  1.2437
#  0.9345
#  1.9528
#  2.2935
#  1.6042
#  1.4048
#  1.4306
#  1.0360
#  1.1662
#  1.0488
#  1.1860
#  1.0954
#  1.0646
#  1.4259
#  0.7165
#  0.8524
#  0.9201
#  1.2517
#  1.3013
#  1.6021
#  0.9381
#  1.2675
#  1.1015
#  0.8206
#  0.9557
#  1.5853
#  1.6166
#  1.0296
#  1.2356
#  0.7257
#  1.5362
#  0.6782
#  2.1323
#  1.5055
#  1.6693
#  1.5663
#  1.7645
#  0.8206
#  1.0646
#  1.0863
#  1.3952
#  0.8832
#  0.6733
#  1.3441
#  0.8406
#  0.6782
#  1.0392
#  1.2000
#  0.9165
#  0.8641
#  1.7889
#  1.5556
#  0.4472
#  1.8385
#  1.7301
#  1.7378
#  1.7720
#  1.0985
#  1.4674
#  0.9055
#  0.6831
#  0.6782
#  1.4922
#  1.1747
#  0.8406
#  1.7907
#  1.5853
#  1.5513
#  0.5416
#  1.6492
#  0.8794
#  1.9630
#  0.7118
#  0.8406
#  1.9967
#  0.6928
#  0.8042
#  1.4353
#  1.3663
#  1.2220
#  0.8124
#  1.2193
#  0.5715
#  1.2166
#  1.5144
#  1.7795
#  0.8718
#  1.7758
#  0.8794
#  1.9131
#  1.6000
#  1.5078
#  0.8406
#  1.3687
#  1.0832
#  1.5556
#  0.9487
#  1.3880
#  1.6104
#  2.3664
#  1.5513
#  1.0708
#  1.3515
#  0.8083
#  0.8679
#  1.5492
#  1.2490
#  1.2596
#  1.3466
#  0.3162
#  0.4690
#  1.1576
#  1.2138
#  1.6371
#  0.8083
#  1.8511
#  0.8981
#  1.5684
#  1.0583
#  0.4761
#  1.6330
#  1.2302
#  1.4491
#  1.4445
#  1.5210
# [torch.FloatTensor of size 151]
